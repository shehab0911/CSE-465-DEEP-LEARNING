# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf

# %%
import string
import numpy as np
import pandas as pd 
from numpy import array
from PIL import Image
import pickle

import matplotlib.pyplot as plt
import keras
import sys, time, os, warnings 
warnings.filterwarnings("ignore")
import re

import tensorflow as tf
from tqdm import tqdm
from nltk.translate.bleu_score import sentence_bleu

from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
#from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
#from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, BatchNormalization
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers.merge import add
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing.text import Tokenizer

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
image_path = "/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/"
dir_Flickr_text = "/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flickr8k.token.txt"

jpgs = os.listdir(image_path)
print("Total Images in Dataset = {}".format(len(jpgs)))
# Out:
# Total Images in Dataset = 16182

# %%
file = open(dir_Flickr_text,'r')
text = file.read()
file.close()

datatxt = []
for line in text.split('\n'):
    col = line.split('\t')
    if len(col) == 1:
        continue
    w = col[0].split("#")
    datatxt.append(w + [col[1].lower()])

data = pd.DataFrame(datatxt,columns=["filename","index","caption"])
data = data.reindex(columns =['index','filename','caption'])
data = data[data['filename'] != '2258277193_586949ec62.jpg.1']


uni_filenames = np.unique(data.filename.values)
data.head()
# Out:
#   index                   filename  \
# 0     0  1000268201_693b08cb0e.jpg
# 1     1  1000268201_693b08cb0e.jpg
# 2     2  1000268201_693b08cb0e.jpg
# 3     3  1000268201_693b08cb0e.jpg
# 4     4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0  a child in a pink dress is climbing up a set o...
# 1              a girl going into a wooden building .
# 2   a little girl climbing into a wooden playhouse .
# 3  a little girl climbing the stairs to her playh...
# 4  a little girl in a pink dress going into a woo...

# %%
from keras.preprocessing.image import load_img, img_to_array

npic = 5
npix = 224
target_size = (npix,npix,3)

count = 1
fig = plt.figure(figsize=(10,20))
for jpgfnm in uni_filenames[25:30]:
    filename = image_path + '/' + jpgfnm
    captions = list(data["caption"].loc[data["filename"]==jpgfnm].values)
    image_load = load_img(filename, target_size=target_size)
    
    ax = fig.add_subplot(npic,2,count,xticks=[],yticks=[])
    ax.imshow(image_load)
    count += 1
    
    ax = fig.add_subplot(npic,2,count)
    plt.axis('off')
    ax.plot()
    ax.set_xlim(0,1)
    ax.set_ylim(0,len(captions))
    for i, caption in enumerate(captions):
        ax.text(0,i,caption,fontsize=20)
    count += 1
plt.show()

# %%
vocabulary = []
for txt in data.caption.values:
    vocabulary.extend(txt.split())
print('Vocabulary Size: %d' % len(set(vocabulary)))
# Out:
# Vocabulary Size: 8918

# %%
img = data["filename"].tolist()
caption = data["caption"].tolist()

# %%
print(f"len(img) : {len(img)}")
print(f"len(caption) : {len(caption)}")
# Out:
# len(img) : 40455
# len(caption) : 40455

# %%
# To remove punctuations
def remove_punctuation(text_original):
    text_no_punctuation = text_original.translate(string.punctuation)
    return(text_no_punctuation)

# To remove single characters
def remove_single_character(text):
    text_len_more_than1 = ""
    for word in text.split():
        if len(word) > 1:
            text_len_more_than1 += " " + word
    return(text_len_more_than1)

# To remove numeric values
def remove_numeric(text):
    text_no_numeric = ""
    for word in text.split():
        isalpha = word.isalpha()
        if isalpha:
            text_no_numeric += " " + word
    return(text_no_numeric)

# %%
def text_clean(text_original):
    text = remove_punctuation(text_original)
    text = remove_single_character(text)
    text = remove_numeric(text)
    return(text)
    
for i, caption in enumerate(data.caption.values):
    newcaption = text_clean(caption)
    data["caption"].iloc[i] = newcaption

# %%
clean_vocabulary = []
for txt in data.caption.values:
    clean_vocabulary.extend(txt.split())
print('Clean Vocabulary Size: %d' % len(set(clean_vocabulary)))
# Out:
# Clean Vocabulary Size: 8357

# %%
PATH = "/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/"
all_captions = []

for caption  in data["caption"].astype(str):
    caption = '<start> ' + caption+ ' <end>'
    all_captions.append(caption)
all_captions[:10]
# Out:
# ['<start>  child in pink dress is climbing up set of stairs in an entry way <end>',
#  '<start>  girl going into wooden building <end>',
#  '<start>  little girl climbing into wooden playhouse <end>',
#  '<start>  little girl climbing the stairs to her playhouse <end>',
#  '<start>  little girl in pink dress going into wooden cabin <end>',
#  '<start>  black dog and spotted dog are fighting <end>',
#  '<start>  black dog and dog playing with each other on the road <end>',
#  '<start>  black dog and white dog with brown spots are staring at each other in the street <end>',
#  '<start>  two dogs of different breeds looking at each other on the road <end>',
#  '<start>  two dogs on pavement moving toward each other <end>']

# %%
all_img_name_vector = []

for annot in data["filename"]:
    full_image_path = PATH + annot

    all_img_name_vector.append(full_image_path)
all_img_name_vector[:10]
# Out:
# ['/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/MyDrive/CSE_465_Image_Caption_Project/Downloads/Flicker8k_Dataset/1001773457_577c3a7d70.jpg']

# %%
print(f"len(all_img_name_vector) : {len(all_img_name_vector)}")
print(f"len(all_captions) : {len(all_captions)}")
# Out:
# len(all_img_name_vector) : 40455
# len(all_captions) : 40455

# %%
def data_limiter(num,total_captions,all_img_name_vector):
  train_captions, img_name_vector = shuffle(total_captions,all_img_name_vector,random_state=1)
  train_captions = train_captions[:num]
  img_name_vector = img_name_vector[:num]
  return train_captions,img_name_vector

# %%
train_captions,img_name_vector = data_limiter(40000,all_captions,all_img_name_vector)

# %%
print(f"len(all_img_name_vector) : {len(img_name_vector)}")
print(f"len(all_captions) : {len(train_captions)}")
# Out:
# len(all_img_name_vector) : 40000
# len(all_captions) : 40000

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 3s 0us/step
# 87924736/87910968 [==============================] - 3s 0us/step

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in tqdm(image_dataset):
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())
# Out:
# 100%|██████████| 506/506 [21:21<00:00,  2.53s/it]

# %% [markdown]
# ### Preprocess and tokenize the captions

# %%
top_k = 5000

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
cap_vector.shape
# Out:
# (40000, 33)

# %% [markdown]
# ### Split the data into training and testing

# %%
img_name_train, img_name_val, cap_train, cap_val = train_test_split(img_name_vector,
                                                                    cap_vector,
                                                                    test_size=0.2,
                                                                    random_state=0)

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (32000, 32000, 8000, 8000)

# %% [markdown]
# ### Create a tf.data dataset for training

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
num_steps = len(img_name_train) // BATCH_SIZE

# %%
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding_1d(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def positional_encoding_2d(row,col,d_model):
  assert d_model % 2 == 0
  # first d_model/2 encode row embedding and second d_model/2 encode column embedding
  row_pos = np.repeat(np.arange(row),col)[:,np.newaxis]
  col_pos = np.repeat(np.expand_dims(np.arange(col),0),row,axis=0).reshape(-1,1)
  angle_rads_row = get_angles(row_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
  angle_rads_col = get_angles(col_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
  #apply sin and cos to odd and even indices resp.
  angle_rads_row[:, 0::2] = np.sin(angle_rads_row[:, 0::2])
  angle_rads_row[:, 1::2] = np.cos(angle_rads_row[:, 1::2])
  angle_rads_col[:, 0::2] = np.sin(angle_rads_col[:, 0::2])
  angle_rads_col[:, 1::2] = np.cos(angle_rads_col[:, 1::2])
  pos_encoding = np.concatenate([angle_rads_row,angle_rads_col],axis=1)[np.newaxis, ...]

  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
  
  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead) 
  but it must be broadcastable for addition.
  
  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable 
          to (..., seq_len_q, seq_len_k). Defaults to None.
    
  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
  
  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)  #adding -Inf where mask is 1 s.t. value get ignored in softmax

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model
    
    assert d_model % self.num_heads == 0
    
    self.depth = d_model // self.num_heads
    
    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)
    
    self.dense = tf.keras.layers.Dense(d_model)
        
  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])
    
  def call(self, v, k, q, mask=None):
    batch_size = tf.shape(q)[0]
    
    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)
    
    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
    
    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)
    
    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention, 
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        
    return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    
  def call(self, x, training, mask=None):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
    
    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
    
    return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)
 
    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
  def call(self, x, enc_output, training, 
           look_ahead_mask=None, padding_mask=None):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    # using look ahead mask so that during self attention current query dont consider future token
    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)
    
    # use padding mask to avoid padded values of both enc_output and dec_input
    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)
    
    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)
    
    return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff,
               row_size,col_size,rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Dense(self.d_model,activation='relu')
    self.pos_encoding = positional_encoding_2d(row_size,col_size, 
                                            self.d_model)
    
    
    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
  
    self.dropout = tf.keras.layers.Dropout(rate)
        
  def call(self, x, training, mask=None):
    # shape(x) = (batch_size,seq_len(H*W),features)
    seq_len = tf.shape(x)[1]
    
    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len(H*W), d_model)
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)
    
    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)
    
    return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding_1d(maximum_position_encoding, d_model)
    
    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)
    
  def call(self, x, enc_output, training, 
           look_ahead_mask=None, padding_mask=None):

    seq_len = tf.shape(x)[1]
    attention_weights = {}
    
    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]
    
    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)
      
      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
    
    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff,row_size,col_size, 
               target_vocab_size,max_pos_encoding, rate=0.1):
    super(Transformer, self).__init__()

    self.encoder = Encoder(num_layers, d_model, num_heads, dff,row_size,col_size, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff, 
                           target_vocab_size,max_pos_encoding, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)
    
  def call(self, inp, tar, training,look_ahead_mask=None, dec_padding_mask=None,enc_padding_mask=None):

    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)
    
    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)
    
    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
    
    return final_output, attention_weights

# %%
num_layer = 4
d_model = 512
dff = 2048
num_heads = 8
row_size = 8
col_size = 8
target_vocab_size = top_k + 1
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()
    
    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps
    
  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  
  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(
    name='train_accuracy')

# %%
transformer = Transformer(num_layer,d_model,num_heads,dff,row_size,col_size,target_vocab_size,max_pos_encoding=target_vocab_size,rate=dropout_rate)

# %%
def create_masks_decoder(tar):
  look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
  dec_target_padding_mask = create_padding_mask(tar)
  combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
  return combined_mask

# %%
@tf.function
def train_step(img_tensor, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]
  
  dec_mask = create_masks_decoder(tar_inp)
  
  with tf.GradientTape() as tape:
    predictions, _ = transformer(img_tensor, tar_inp, 
                                 True,  
                                 dec_mask)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)    
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
  
  train_loss(loss)
  train_accuracy(tar_real, predictions)

# %%
for epoch in range(100):
  start = time.time()
  
  train_loss.reset_states()
  train_accuracy.reset_states()
  
  for (batch, (img_tensor, tar)) in enumerate(dataset):
    train_step(img_tensor, tar)
    
    if batch % 50 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
          epoch + 1, batch, train_loss.result(), train_accuracy.result()))
      
    
  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))

  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 8.6354 Accuracy 0.0005
# Epoch 1 Batch 50 Loss 8.1871 Accuracy 0.0181
# Epoch 1 Batch 100 Loss 7.7526 Accuracy 0.0246
# Epoch 1 Batch 150 Loss 7.4383 Accuracy 0.0274
# Epoch 1 Batch 200 Loss 7.1390 Accuracy 0.0304
# Epoch 1 Batch 250 Loss 6.8613 Accuracy 0.0340
# Epoch 1 Batch 300 Loss 6.6091 Accuracy 0.0379
# Epoch 1 Batch 350 Loss 6.3937 Accuracy 0.0416
# Epoch 1 Batch 400 Loss 6.1976 Accuracy 0.0450
# Epoch 1 Batch 450 Loss 6.0264 Accuracy 0.0484
# Epoch 2 Batch 0 Loss 4.4030 Accuracy 0.0796
# Epoch 2 Batch 50 Loss 4.3872 Accuracy 0.0806
# Epoch 2 Batch 100 Loss 4.3452 Accuracy 0.0820
# Epoch 2 Batch 150 Loss 4.2970 Accuracy 0.0827
# Epoch 2 Batch 200 Loss 4.2434 Accuracy 0.0836
# Epoch 2 Batch 250 Loss 4.2033 Accuracy 0.0845
# Epoch 2 Batch 300 Loss 4.1649 Accuracy 0.0855
# Epoch 2 Batch 350 Loss 4.1226 Accuracy 0.0863
# Epoch 2 Batch 400 Loss 4.0839 Accuracy 0.0873
# Epoch 2 Batch 450 Loss 4.0502 Accuracy 0.0881
# Epoch 2 Loss 4.0194 Accuracy 0.0887
# Time taken for 1 epoch: 116.13426065444946 secs
#
# Epoch 3 Batch 0 Loss 3.7974 Accuracy 0.0947
# Epoch 3 Batch 50 Loss 3.6809 Accuracy 0.0982
# Epoch 3 Batch 100 Loss 3.6576 Accuracy 0.0987
# Epoch 3 Batch 150 Loss 3.6383 Accuracy 0.0985
# Epoch 3 Batch 200 Loss 3.6176 Accuracy 0.0989
# Epoch 3 Batch 250 Loss 3.5998 Accuracy 0.0992
# Epoch 3 Batch 300 Loss 3.5850 Accuracy 0.0996
# Epoch 3 Batch 350 Loss 3.5672 Accuracy 0.1001
# Epoch 3 Batch 400 Loss 3.5494 Accuracy 0.1005
# Epoch 3 Batch 450 Loss 3.5343 Accuracy 0.1008
# Epoch 3 Loss 3.5202 Accuracy 0.1011
# Time taken for 1 epoch: 117.2874104976654 secs
#
# Epoch 4 Batch 0 Loss 3.4766 Accuracy 0.0952
# Epoch 4 Batch 50 Loss 3.3836 Accuracy 0.1044
# Epoch 4 Batch 100 Loss 3.3620 Accuracy 0.1055
# Epoch 4 Batch 150 Loss 3.3473 Accuracy 0.1061
# Epoch 4 Batch 200 Loss 3.3284 Accuracy 0.1062
# Epoch 4 Batch 250 Loss 3.3161 Accuracy 0.1067
# Epoch 4 Batch 300 Loss 3.3066 Accuracy 0.1071
# Epoch 4 Batch 350 Loss 3.2977 Accuracy 0.1073
# Epoch 4 Batch 400 Loss 3.2856 Accuracy 0.1074
# Epoch 4 Batch 450 Loss 3.2732 Accuracy 0.1078
# Epoch 4 Loss 3.2663 Accuracy 0.1080
# Time taken for 1 epoch: 117.19982576370239 secs
#
# Epoch 5 Batch 0 Loss 2.9534 Accuracy 0.1079
# Epoch 5 Batch 50 Loss 3.1830 Accuracy 0.1113
# Epoch 5 Batch 100 Loss 3.1695 Accuracy 0.1120
# Epoch 5 Batch 150 Loss 3.1568 Accuracy 0.1117
# Epoch 5 Batch 200 Loss 3.1415 Accuracy 0.1119
# Epoch 5 Batch 250 Loss 3.1372 Accuracy 0.1119
# Epoch 5 Batch 300 Loss 3.1277 Accuracy 0.1124
# Epoch 5 Batch 350 Loss 3.1209 Accuracy 0.1125
# Epoch 5 Batch 400 Loss 3.1127 Accuracy 0.1127
# Epoch 5 Batch 450 Loss 3.1054 Accuracy 0.1130
# Epoch 5 Loss 3.1001 Accuracy 0.1130
# Time taken for 1 epoch: 116.84057331085205 secs
#
# Epoch 6 Batch 0 Loss 3.0399 Accuracy 0.1064
# Epoch 6 Batch 50 Loss 3.0287 Accuracy 0.1164
# Epoch 6 Batch 100 Loss 3.0338 Accuracy 0.1158
# Epoch 6 Batch 150 Loss 3.0216 Accuracy 0.1159
# Epoch 6 Batch 200 Loss 3.0112 Accuracy 0.1160
# Epoch 6 Batch 250 Loss 3.0102 Accuracy 0.1159
# Epoch 6 Batch 300 Loss 3.0079 Accuracy 0.1159
# Epoch 6 Batch 350 Loss 3.0012 Accuracy 0.1161
# Epoch 6 Batch 400 Loss 2.9948 Accuracy 0.1160
# Epoch 6 Batch 450 Loss 2.9900 Accuracy 0.1162
# Epoch 6 Loss 2.9850 Accuracy 0.1164
# Time taken for 1 epoch: 116.54481434822083 secs
#
# Epoch 7 Batch 0 Loss 3.1018 Accuracy 0.1040
# Epoch 7 Batch 50 Loss 2.9110 Accuracy 0.1193
# Epoch 7 Batch 100 Loss 2.9333 Accuracy 0.1187
# Epoch 7 Batch 150 Loss 2.9306 Accuracy 0.1183
# Epoch 7 Batch 200 Loss 2.9200 Accuracy 0.1183
# Epoch 7 Batch 250 Loss 2.9194 Accuracy 0.1184
# Epoch 7 Batch 300 Loss 2.9160 Accuracy 0.1185
# Epoch 7 Batch 350 Loss 2.9156 Accuracy 0.1184
# Epoch 7 Batch 400 Loss 2.9121 Accuracy 0.1181
# Epoch 7 Batch 450 Loss 2.9074 Accuracy 0.1183
# Epoch 7 Loss 2.9057 Accuracy 0.1184
# Time taken for 1 epoch: 116.34318709373474 secs
#
# Epoch 8 Batch 0 Loss 2.7384 Accuracy 0.1265
# Epoch 8 Batch 50 Loss 2.8843 Accuracy 0.1189
# Epoch 8 Batch 100 Loss 2.8834 Accuracy 0.1200
# Epoch 8 Batch 150 Loss 2.8784 Accuracy 0.1193
# Epoch 8 Batch 200 Loss 2.8715 Accuracy 0.1192
# Epoch 8 Batch 250 Loss 2.8758 Accuracy 0.1189
# Epoch 8 Batch 300 Loss 2.8755 Accuracy 0.1191
# Epoch 8 Batch 350 Loss 2.8713 Accuracy 0.1192
# Epoch 8 Batch 400 Loss 2.8710 Accuracy 0.1191
# Epoch 8 Batch 450 Loss 2.8703 Accuracy 0.1190
# Epoch 8 Loss 2.8685 Accuracy 0.1190
# Time taken for 1 epoch: 116.18283772468567 secs
#
# Epoch 9 Batch 0 Loss 2.9531 Accuracy 0.1211
# Epoch 9 Batch 50 Loss 2.8453 Accuracy 0.1188
# Epoch 9 Batch 100 Loss 2.8430 Accuracy 0.1200
# Epoch 9 Batch 150 Loss 2.8418 Accuracy 0.1196
# Epoch 9 Batch 200 Loss 2.8396 Accuracy 0.1196
# Epoch 9 Batch 250 Loss 2.8339 Accuracy 0.1197
# Epoch 9 Batch 300 Loss 2.8324 Accuracy 0.1201
# Epoch 9 Batch 350 Loss 2.8257 Accuracy 0.1202
# Epoch 9 Batch 400 Loss 2.8166 Accuracy 0.1204
# Epoch 9 Batch 450 Loss 2.8089 Accuracy 0.1205
# Epoch 9 Loss 2.8051 Accuracy 0.1208
# Time taken for 1 epoch: 115.80113172531128 secs
#
# Epoch 10 Batch 0 Loss 2.7027 Accuracy 0.1304
# Epoch 10 Batch 50 Loss 2.7407 Accuracy 0.1233
# Epoch 10 Batch 100 Loss 2.7349 Accuracy 0.1238
# Epoch 10 Batch 150 Loss 2.7281 Accuracy 0.1237
# Epoch 10 Batch 200 Loss 2.7220 Accuracy 0.1232
# Epoch 10 Batch 250 Loss 2.7187 Accuracy 0.1235
# Epoch 10 Batch 300 Loss 2.7144 Accuracy 0.1239
# Epoch 10 Batch 350 Loss 2.7066 Accuracy 0.1240
# Epoch 10 Batch 400 Loss 2.7008 Accuracy 0.1240
# Epoch 10 Batch 450 Loss 2.6913 Accuracy 0.1245
# Epoch 10 Loss 2.6868 Accuracy 0.1246
# Time taken for 1 epoch: 115.84084343910217 secs
#
# Epoch 11 Batch 0 Loss 2.6830 Accuracy 0.1182
# Epoch 11 Batch 50 Loss 2.6161 Accuracy 0.1268
# Epoch 11 Batch 100 Loss 2.6226 Accuracy 0.1279
# Epoch 11 Batch 150 Loss 2.6186 Accuracy 0.1276
# Epoch 11 Batch 200 Loss 2.6103 Accuracy 0.1277
# Epoch 11 Batch 250 Loss 2.6098 Accuracy 0.1275
# Epoch 11 Batch 300 Loss 2.6051 Accuracy 0.1279
# Epoch 11 Batch 350 Loss 2.5977 Accuracy 0.1280
# Epoch 11 Batch 400 Loss 2.5892 Accuracy 0.1284
# Epoch 11 Batch 450 Loss 2.5812 Accuracy 0.1287
# Epoch 11 Loss 2.5789 Accuracy 0.1288
# Time taken for 1 epoch: 115.79274153709412 secs
#
# Epoch 12 Batch 0 Loss 2.5379 Accuracy 0.1255
# Epoch 12 Batch 50 Loss 2.5172 Accuracy 0.1313
# Epoch 12 Batch 100 Loss 2.5140 Accuracy 0.1323
# Epoch 12 Batch 150 Loss 2.5083 Accuracy 0.1323
# Epoch 12 Batch 200 Loss 2.5067 Accuracy 0.1315
# Epoch 12 Batch 250 Loss 2.5038 Accuracy 0.1319
# Epoch 12 Batch 300 Loss 2.5000 Accuracy 0.1319
# Epoch 12 Batch 350 Loss 2.4947 Accuracy 0.1321
# Epoch 12 Batch 400 Loss 2.4853 Accuracy 0.1323
# Epoch 12 Batch 450 Loss 2.4789 Accuracy 0.1326
# Epoch 12 Loss 2.4735 Accuracy 0.1329
# Time taken for 1 epoch: 115.86131882667542 secs
#
# Epoch 13 Batch 0 Loss 2.4162 Accuracy 0.1431
# Epoch 13 Batch 50 Loss 2.4018 Accuracy 0.1361
# Epoch 13 Batch 100 Loss 2.4015 Accuracy 0.1365
# Epoch 13 Batch 150 Loss 2.4012 Accuracy 0.1361
# Epoch 13 Batch 200 Loss 2.4003 Accuracy 0.1356
# Epoch 13 Batch 250 Loss 2.3962 Accuracy 0.1360
# Epoch 13 Batch 300 Loss 2.3923 Accuracy 0.1363
# Epoch 13 Batch 350 Loss 2.3875 Accuracy 0.1364
# Epoch 13 Batch 400 Loss 2.3794 Accuracy 0.1367
# Epoch 13 Batch 450 Loss 2.3729 Accuracy 0.1370
# Epoch 13 Loss 2.3684 Accuracy 0.1371
# Time taken for 1 epoch: 115.92784094810486 secs
#
# Epoch 14 Batch 0 Loss 2.3446 Accuracy 0.1392
# Epoch 14 Batch 50 Loss 2.3286 Accuracy 0.1385
# Epoch 14 Batch 100 Loss 2.3095 Accuracy 0.1404
# Epoch 14 Batch 150 Loss 2.3091 Accuracy 0.1399
# Epoch 14 Batch 200 Loss 2.3015 Accuracy 0.1398
# Epoch 14 Batch 250 Loss 2.3023 Accuracy 0.1398
# Epoch 14 Batch 300 Loss 2.2969 Accuracy 0.1402
# Epoch 14 Batch 350 Loss 2.2910 Accuracy 0.1403
# Epoch 14 Batch 400 Loss 2.2838 Accuracy 0.1406
# Epoch 14 Batch 450 Loss 2.2753 Accuracy 0.1410
# Epoch 14 Loss 2.2724 Accuracy 0.1411
# Time taken for 1 epoch: 115.72015881538391 secs
#
# Epoch 15 Batch 0 Loss 2.1167 Accuracy 0.1436
# Epoch 15 Batch 50 Loss 2.2339 Accuracy 0.1416
# Epoch 15 Batch 100 Loss 2.2247 Accuracy 0.1439
# Epoch 15 Batch 150 Loss 2.2180 Accuracy 0.1441
# Epoch 15 Batch 200 Loss 2.2113 Accuracy 0.1437
# Epoch 15 Batch 250 Loss 2.2113 Accuracy 0.1442
# Epoch 15 Batch 300 Loss 2.2059 Accuracy 0.1445
# Epoch 15 Batch 350 Loss 2.1994 Accuracy 0.1447
# Epoch 15 Batch 400 Loss 2.1940 Accuracy 0.1448
# Epoch 15 Batch 450 Loss 2.1875 Accuracy 0.1451
# Epoch 15 Loss 2.1827 Accuracy 0.1453
# Time taken for 1 epoch: 115.72392964363098 secs
#
# Epoch 16 Batch 0 Loss 2.1098 Accuracy 0.1523
# Epoch 16 Batch 50 Loss 2.1293 Accuracy 0.1479
# Epoch 16 Batch 100 Loss 2.1280 Accuracy 0.1482
# Epoch 16 Batch 150 Loss 2.1185 Accuracy 0.1484
# Epoch 16 Batch 200 Loss 2.1158 Accuracy 0.1484
# Epoch 16 Batch 250 Loss 2.1157 Accuracy 0.1484
# Epoch 16 Batch 300 Loss 2.1154 Accuracy 0.1486
# Epoch 16 Batch 350 Loss 2.1100 Accuracy 0.1487
# Epoch 16 Batch 400 Loss 2.1037 Accuracy 0.1489
# Epoch 16 Batch 450 Loss 2.0968 Accuracy 0.1491
# Epoch 16 Loss 2.0926 Accuracy 0.1493
# Time taken for 1 epoch: 115.74150776863098 secs
#
# Epoch 17 Batch 0 Loss 2.0455 Accuracy 0.1396
# Epoch 17 Batch 50 Loss 2.0477 Accuracy 0.1516
# Epoch 17 Batch 100 Loss 2.0357 Accuracy 0.1532
# Epoch 17 Batch 150 Loss 2.0368 Accuracy 0.1527
# Epoch 17 Batch 200 Loss 2.0309 Accuracy 0.1529
# Epoch 17 Batch 250 Loss 2.0311 Accuracy 0.1529
# Epoch 17 Batch 300 Loss 2.0290 Accuracy 0.1530
# Epoch 17 Batch 350 Loss 2.0258 Accuracy 0.1531
# Epoch 17 Batch 400 Loss 2.0191 Accuracy 0.1533
# Epoch 17 Batch 450 Loss 2.0131 Accuracy 0.1536
# Epoch 17 Loss 2.0072 Accuracy 0.1539
# Time taken for 1 epoch: 115.61466526985168 secs
#
# Epoch 18 Batch 0 Loss 1.9124 Accuracy 0.1699
# Epoch 18 Batch 50 Loss 1.9747 Accuracy 0.1551
# Epoch 18 Batch 100 Loss 1.9622 Accuracy 0.1566
# Epoch 18 Batch 150 Loss 1.9578 Accuracy 0.1568
# Epoch 18 Batch 200 Loss 1.9519 Accuracy 0.1563
# Epoch 18 Batch 250 Loss 1.9502 Accuracy 0.1566
# Epoch 18 Batch 300 Loss 1.9488 Accuracy 0.1567
# Epoch 18 Batch 350 Loss 1.9451 Accuracy 0.1569
# Epoch 18 Batch 400 Loss 1.9383 Accuracy 0.1571
# Epoch 18 Batch 450 Loss 1.9319 Accuracy 0.1574
# Epoch 18 Loss 1.9275 Accuracy 0.1576
# Time taken for 1 epoch: 115.69988942146301 secs
#
# Epoch 19 Batch 0 Loss 1.8044 Accuracy 0.1611
# Epoch 19 Batch 50 Loss 1.8989 Accuracy 0.1602
# Epoch 19 Batch 100 Loss 1.8808 Accuracy 0.1611
# Epoch 19 Batch 150 Loss 1.8717 Accuracy 0.1610
# Epoch 19 Batch 200 Loss 1.8704 Accuracy 0.1609
# Epoch 19 Batch 250 Loss 1.8676 Accuracy 0.1612
# Epoch 19 Batch 300 Loss 1.8654 Accuracy 0.1614
# Epoch 19 Batch 350 Loss 1.8639 Accuracy 0.1612
# Epoch 19 Batch 400 Loss 1.8576 Accuracy 0.1615
# Epoch 19 Batch 450 Loss 1.8510 Accuracy 0.1619
# Epoch 19 Loss 1.8477 Accuracy 0.1621
# Time taken for 1 epoch: 115.64862942695618 secs
#
# Epoch 20 Batch 0 Loss 1.8274 Accuracy 0.1567
# Epoch 20 Batch 50 Loss 1.8082 Accuracy 0.1655
# Epoch 20 Batch 100 Loss 1.8045 Accuracy 0.1658
# Epoch 20 Batch 150 Loss 1.7975 Accuracy 0.1655
# Epoch 20 Batch 200 Loss 1.7919 Accuracy 0.1655
# Epoch 20 Batch 250 Loss 1.7916 Accuracy 0.1657
# Epoch 20 Batch 300 Loss 1.7892 Accuracy 0.1660
# Epoch 20 Batch 350 Loss 1.7861 Accuracy 0.1662
# Epoch 20 Batch 400 Loss 1.7817 Accuracy 0.1663
# Epoch 20 Batch 450 Loss 1.7761 Accuracy 0.1666
# Epoch 20 Loss 1.7726 Accuracy 0.1668
# Time taken for 1 epoch: 115.71770715713501 secs
#
# Epoch 21 Batch 0 Loss 1.6990 Accuracy 0.1743
# Epoch 21 Batch 50 Loss 1.7457 Accuracy 0.1684
# Epoch 21 Batch 100 Loss 1.7329 Accuracy 0.1695
# Epoch 21 Batch 150 Loss 1.7322 Accuracy 0.1694
# Epoch 21 Batch 200 Loss 1.7266 Accuracy 0.1694
# Epoch 21 Batch 250 Loss 1.7215 Accuracy 0.1698
# Epoch 21 Batch 300 Loss 1.7175 Accuracy 0.1699
# Epoch 21 Batch 350 Loss 1.7138 Accuracy 0.1701
# Epoch 21 Batch 400 Loss 1.7085 Accuracy 0.1702
# Epoch 21 Batch 450 Loss 1.7042 Accuracy 0.1705
# Epoch 21 Loss 1.7007 Accuracy 0.1706
# Time taken for 1 epoch: 115.6123104095459 secs
#
# Epoch 22 Batch 0 Loss 1.6612 Accuracy 0.1704
# Epoch 22 Batch 50 Loss 1.6701 Accuracy 0.1729
# Epoch 22 Batch 100 Loss 1.6603 Accuracy 0.1745
# Epoch 22 Batch 150 Loss 1.6549 Accuracy 0.1740
# Epoch 22 Batch 200 Loss 1.6534 Accuracy 0.1737
# Epoch 22 Batch 250 Loss 1.6513 Accuracy 0.1741
# Epoch 22 Batch 300 Loss 1.6475 Accuracy 0.1742
# Epoch 22 Batch 350 Loss 1.6458 Accuracy 0.1743
# Epoch 22 Batch 400 Loss 1.6400 Accuracy 0.1745
# Epoch 22 Batch 450 Loss 1.6351 Accuracy 0.1747
# Epoch 22 Loss 1.6323 Accuracy 0.1749
# Time taken for 1 epoch: 115.63599371910095 secs
#
# Epoch 23 Batch 0 Loss 1.5633 Accuracy 0.1719
# Epoch 23 Batch 50 Loss 1.5972 Accuracy 0.1782
# Epoch 23 Batch 100 Loss 1.5950 Accuracy 0.1785
# Epoch 23 Batch 150 Loss 1.5906 Accuracy 0.1784
# Epoch 23 Batch 200 Loss 1.5915 Accuracy 0.1776
# Epoch 23 Batch 250 Loss 1.5892 Accuracy 0.1779
# Epoch 23 Batch 300 Loss 1.5874 Accuracy 0.1781
# Epoch 23 Batch 350 Loss 1.5829 Accuracy 0.1784
# Epoch 23 Batch 400 Loss 1.5778 Accuracy 0.1787
# Epoch 23 Batch 450 Loss 1.5732 Accuracy 0.1789
# Epoch 23 Loss 1.5702 Accuracy 0.1791
# Time taken for 1 epoch: 115.66929626464844 secs
#
# Epoch 24 Batch 0 Loss 1.6096 Accuracy 0.1680
# Epoch 24 Batch 50 Loss 1.5433 Accuracy 0.1804
# Epoch 24 Batch 100 Loss 1.5410 Accuracy 0.1816
# Epoch 24 Batch 150 Loss 1.5371 Accuracy 0.1814
# Epoch 24 Batch 200 Loss 1.5354 Accuracy 0.1811
# Epoch 24 Batch 250 Loss 1.5303 Accuracy 0.1814
# Epoch 24 Batch 300 Loss 1.5272 Accuracy 0.1815
# Epoch 24 Batch 350 Loss 1.5245 Accuracy 0.1816
# Epoch 24 Batch 400 Loss 1.5202 Accuracy 0.1817
# Epoch 24 Batch 450 Loss 1.5153 Accuracy 0.1822
# Epoch 24 Loss 1.5118 Accuracy 0.1824
# Time taken for 1 epoch: 115.5729603767395 secs
#
# Epoch 25 Batch 0 Loss 1.5045 Accuracy 0.1938
# Epoch 25 Batch 50 Loss 1.4902 Accuracy 0.1842
# Epoch 25 Batch 100 Loss 1.4784 Accuracy 0.1852
# Epoch 25 Batch 150 Loss 1.4743 Accuracy 0.1854
# Epoch 25 Batch 200 Loss 1.4707 Accuracy 0.1852
# Epoch 25 Batch 250 Loss 1.4671 Accuracy 0.1859
# Epoch 25 Batch 300 Loss 1.4636 Accuracy 0.1862
# Epoch 25 Batch 350 Loss 1.4604 Accuracy 0.1864
# Epoch 25 Batch 400 Loss 1.4559 Accuracy 0.1864
# Epoch 25 Batch 450 Loss 1.4516 Accuracy 0.1868
# Epoch 25 Loss 1.4489 Accuracy 0.1869
# Time taken for 1 epoch: 115.60541081428528 secs
#
# Epoch 26 Batch 0 Loss 1.3337 Accuracy 0.1831
# Epoch 26 Batch 50 Loss 1.4318 Accuracy 0.1876
# Epoch 26 Batch 100 Loss 1.4129 Accuracy 0.1896
# Epoch 26 Batch 150 Loss 1.4145 Accuracy 0.1890
# Epoch 26 Batch 200 Loss 1.4110 Accuracy 0.1890
# Epoch 26 Batch 250 Loss 1.4099 Accuracy 0.1893
# Epoch 26 Batch 300 Loss 1.4061 Accuracy 0.1894
# Epoch 26 Batch 350 Loss 1.4034 Accuracy 0.1897
# Epoch 26 Batch 400 Loss 1.3992 Accuracy 0.1900
# Epoch 26 Batch 450 Loss 1.3966 Accuracy 0.1902
# Epoch 26 Loss 1.3940 Accuracy 0.1904
# Time taken for 1 epoch: 115.54793882369995 secs
#
# Epoch 27 Batch 0 Loss 1.3593 Accuracy 0.1953
# Epoch 27 Batch 50 Loss 1.3814 Accuracy 0.1929
# Epoch 27 Batch 100 Loss 1.3713 Accuracy 0.1932
# Epoch 27 Batch 150 Loss 1.3661 Accuracy 0.1934
# Epoch 27 Batch 200 Loss 1.3632 Accuracy 0.1931
# Epoch 27 Batch 250 Loss 1.3598 Accuracy 0.1931
# Epoch 27 Batch 300 Loss 1.3572 Accuracy 0.1933
# Epoch 27 Batch 350 Loss 1.3563 Accuracy 0.1933
# Epoch 27 Batch 400 Loss 1.3525 Accuracy 0.1936
# Epoch 27 Batch 450 Loss 1.3477 Accuracy 0.1939
# Epoch 27 Loss 1.3452 Accuracy 0.1940
# Time taken for 1 epoch: 115.65501856803894 secs
#
# Epoch 28 Batch 0 Loss 1.2214 Accuracy 0.1899
# Epoch 28 Batch 50 Loss 1.3289 Accuracy 0.1956
# Epoch 28 Batch 100 Loss 1.3189 Accuracy 0.1972
# Epoch 28 Batch 150 Loss 1.3160 Accuracy 0.1963
# Epoch 28 Batch 200 Loss 1.3134 Accuracy 0.1964
# Epoch 28 Batch 250 Loss 1.3108 Accuracy 0.1965
# Epoch 28 Batch 300 Loss 1.3074 Accuracy 0.1969
# Epoch 28 Batch 350 Loss 1.3019 Accuracy 0.1974
# Epoch 28 Batch 400 Loss 1.2991 Accuracy 0.1973
# Epoch 28 Batch 450 Loss 1.2969 Accuracy 0.1975
# Epoch 28 Loss 1.2940 Accuracy 0.1977
# Time taken for 1 epoch: 115.53806376457214 secs
#
# Epoch 29 Batch 0 Loss 1.3637 Accuracy 0.1782
# Epoch 29 Batch 50 Loss 1.2899 Accuracy 0.1981
# Epoch 29 Batch 100 Loss 1.2844 Accuracy 0.1992
# Epoch 29 Batch 150 Loss 1.2789 Accuracy 0.1996
# Epoch 29 Batch 200 Loss 1.2727 Accuracy 0.1991
# Epoch 29 Batch 250 Loss 1.2699 Accuracy 0.1996
# Epoch 29 Batch 300 Loss 1.2641 Accuracy 0.2000
# Epoch 29 Batch 350 Loss 1.2607 Accuracy 0.2003
# Epoch 29 Batch 400 Loss 1.2561 Accuracy 0.2004
# Epoch 29 Batch 450 Loss 1.2540 Accuracy 0.2005
# Epoch 29 Loss 1.2516 Accuracy 0.2005
# Time taken for 1 epoch: 115.46595931053162 secs
#
# Epoch 30 Batch 0 Loss 1.3163 Accuracy 0.1846
# Epoch 30 Batch 50 Loss 1.2417 Accuracy 0.2012
# Epoch 30 Batch 100 Loss 1.2358 Accuracy 0.2037
# Epoch 30 Batch 150 Loss 1.2286 Accuracy 0.2039
# Epoch 30 Batch 200 Loss 1.2242 Accuracy 0.2033
# Epoch 30 Batch 250 Loss 1.2211 Accuracy 0.2036
# Epoch 30 Batch 300 Loss 1.2192 Accuracy 0.2036
# Epoch 30 Batch 350 Loss 1.2161 Accuracy 0.2036
# Epoch 30 Batch 400 Loss 1.2122 Accuracy 0.2037
# Epoch 30 Batch 450 Loss 1.2089 Accuracy 0.2042
# Epoch 30 Loss 1.2059 Accuracy 0.2043
# Time taken for 1 epoch: 115.56187295913696 secs
#
# Epoch 31 Batch 0 Loss 1.2575 Accuracy 0.1943
# Epoch 31 Batch 50 Loss 1.1942 Accuracy 0.2059
# Epoch 31 Batch 100 Loss 1.1886 Accuracy 0.2069
# Epoch 31 Batch 150 Loss 1.1822 Accuracy 0.2070
# Epoch 31 Batch 200 Loss 1.1775 Accuracy 0.2069
# Epoch 31 Batch 250 Loss 1.1760 Accuracy 0.2070
# Epoch 31 Batch 300 Loss 1.1741 Accuracy 0.2070
# Epoch 31 Batch 350 Loss 1.1726 Accuracy 0.2070
# Epoch 31 Batch 400 Loss 1.1707 Accuracy 0.2070
# Epoch 31 Batch 450 Loss 1.1676 Accuracy 0.2070
# Epoch 31 Loss 1.1649 Accuracy 0.2073
# Time taken for 1 epoch: 115.45723581314087 secs
#
# Epoch 32 Batch 0 Loss 1.2855 Accuracy 0.1929
# Epoch 32 Batch 50 Loss 1.1594 Accuracy 0.2084
# Epoch 32 Batch 100 Loss 1.1497 Accuracy 0.2101
# Epoch 32 Batch 150 Loss 1.1462 Accuracy 0.2100
# Epoch 32 Batch 200 Loss 1.1434 Accuracy 0.2095
# Epoch 32 Batch 250 Loss 1.1388 Accuracy 0.2095
# Epoch 32 Batch 300 Loss 1.1361 Accuracy 0.2097
# Epoch 32 Batch 350 Loss 1.1337 Accuracy 0.2096
# Epoch 32 Batch 400 Loss 1.1301 Accuracy 0.2100
# Epoch 32 Batch 450 Loss 1.1266 Accuracy 0.2102
# Epoch 32 Loss 1.1234 Accuracy 0.2104
# Time taken for 1 epoch: 115.48682761192322 secs
#
# Epoch 33 Batch 0 Loss 1.1899 Accuracy 0.2031
# Epoch 33 Batch 50 Loss 1.1046 Accuracy 0.2118
# Epoch 33 Batch 100 Loss 1.1059 Accuracy 0.2124
# Epoch 33 Batch 150 Loss 1.1070 Accuracy 0.2124
# Epoch 33 Batch 200 Loss 1.1067 Accuracy 0.2114
# Epoch 33 Batch 250 Loss 1.1037 Accuracy 0.2119
# Epoch 33 Batch 300 Loss 1.0984 Accuracy 0.2122
# Epoch 33 Batch 350 Loss 1.0966 Accuracy 0.2128
# Epoch 33 Batch 400 Loss 1.0948 Accuracy 0.2126
# Epoch 33 Batch 450 Loss 1.0913 Accuracy 0.2129
# Epoch 33 Loss 1.0887 Accuracy 0.2131
# Time taken for 1 epoch: 115.56884050369263 secs
#
# Epoch 34 Batch 0 Loss 1.2184 Accuracy 0.2100
# Epoch 34 Batch 50 Loss 1.0804 Accuracy 0.2146
# Epoch 34 Batch 100 Loss 1.0667 Accuracy 0.2156
# Epoch 34 Batch 150 Loss 1.0615 Accuracy 0.2162
# Epoch 34 Batch 200 Loss 1.0601 Accuracy 0.2154
# Epoch 34 Batch 250 Loss 1.0588 Accuracy 0.2158
# Epoch 34 Batch 300 Loss 1.0582 Accuracy 0.2157
# Epoch 34 Batch 350 Loss 1.0556 Accuracy 0.2161
# Epoch 34 Batch 400 Loss 1.0511 Accuracy 0.2161
# Epoch 34 Batch 450 Loss 1.0478 Accuracy 0.2165
# Epoch 34 Loss 1.0457 Accuracy 0.2167
# Time taken for 1 epoch: 115.53237915039062 secs
#
# Epoch 35 Batch 0 Loss 1.0790 Accuracy 0.2153
# Epoch 35 Batch 50 Loss 1.0449 Accuracy 0.2163
# Epoch 35 Batch 100 Loss 1.0368 Accuracy 0.2185
# Epoch 35 Batch 150 Loss 1.0332 Accuracy 0.2178
# Epoch 35 Batch 200 Loss 1.0306 Accuracy 0.2176
# Epoch 35 Batch 250 Loss 1.0291 Accuracy 0.2181
# Epoch 35 Batch 300 Loss 1.0252 Accuracy 0.2185
# Epoch 35 Batch 350 Loss 1.0229 Accuracy 0.2187
# Epoch 35 Batch 400 Loss 1.0201 Accuracy 0.2189
# Epoch 35 Batch 450 Loss 1.0170 Accuracy 0.2192
# Epoch 35 Loss 1.0134 Accuracy 0.2194
# Time taken for 1 epoch: 115.52298545837402 secs
#
# Epoch 36 Batch 0 Loss 1.0292 Accuracy 0.2202
# Epoch 36 Batch 50 Loss 1.0118 Accuracy 0.2200
# Epoch 36 Batch 100 Loss 1.0109 Accuracy 0.2208
# Epoch 36 Batch 150 Loss 1.0018 Accuracy 0.2210
# Epoch 36 Batch 200 Loss 1.0006 Accuracy 0.2206
# Epoch 36 Batch 250 Loss 0.9962 Accuracy 0.2210
# Epoch 36 Batch 300 Loss 0.9932 Accuracy 0.2214
# Epoch 36 Batch 350 Loss 0.9921 Accuracy 0.2213
# Epoch 36 Batch 400 Loss 0.9884 Accuracy 0.2213
# Epoch 36 Batch 450 Loss 0.9862 Accuracy 0.2216
# Epoch 36 Loss 0.9838 Accuracy 0.2218
# Time taken for 1 epoch: 115.61203813552856 secs
#
# Epoch 37 Batch 0 Loss 1.0490 Accuracy 0.2163
# Epoch 37 Batch 50 Loss 0.9808 Accuracy 0.2231
# Epoch 37 Batch 100 Loss 0.9748 Accuracy 0.2244
# Epoch 37 Batch 150 Loss 0.9678 Accuracy 0.2242
# Epoch 37 Batch 200 Loss 0.9655 Accuracy 0.2240
# Epoch 37 Batch 250 Loss 0.9664 Accuracy 0.2240
# Epoch 37 Batch 300 Loss 0.9620 Accuracy 0.2242
# Epoch 37 Batch 350 Loss 0.9589 Accuracy 0.2246
# Epoch 37 Batch 400 Loss 0.9560 Accuracy 0.2245
# Epoch 37 Batch 450 Loss 0.9527 Accuracy 0.2249
# Epoch 37 Loss 0.9502 Accuracy 0.2250
# Time taken for 1 epoch: 115.50373077392578 secs
#
# Epoch 38 Batch 0 Loss 0.9742 Accuracy 0.2231
# Epoch 38 Batch 50 Loss 0.9391 Accuracy 0.2251
# Epoch 38 Batch 100 Loss 0.9358 Accuracy 0.2267
# Epoch 38 Batch 150 Loss 0.9354 Accuracy 0.2265
# Epoch 38 Batch 200 Loss 0.9349 Accuracy 0.2257
# Epoch 38 Batch 250 Loss 0.9326 Accuracy 0.2260
# Epoch 38 Batch 300 Loss 0.9282 Accuracy 0.2267
# Epoch 38 Batch 350 Loss 0.9267 Accuracy 0.2266
# Epoch 38 Batch 400 Loss 0.9243 Accuracy 0.2267
# Epoch 38 Batch 450 Loss 0.9216 Accuracy 0.2269
# Epoch 38 Loss 0.9204 Accuracy 0.2270
# Time taken for 1 epoch: 115.53386449813843 secs
#
# Epoch 39 Batch 0 Loss 1.0227 Accuracy 0.2114
# Epoch 39 Batch 50 Loss 0.9084 Accuracy 0.2294
# Epoch 39 Batch 100 Loss 0.9092 Accuracy 0.2296
# Epoch 39 Batch 150 Loss 0.9100 Accuracy 0.2284
# Epoch 39 Batch 200 Loss 0.9100 Accuracy 0.2279
# Epoch 39 Batch 250 Loss 0.9071 Accuracy 0.2279
# Epoch 39 Batch 300 Loss 0.9031 Accuracy 0.2287
# Epoch 39 Batch 350 Loss 0.9007 Accuracy 0.2288
# Epoch 39 Batch 400 Loss 0.8986 Accuracy 0.2287
# Epoch 39 Batch 450 Loss 0.8974 Accuracy 0.2290
# Epoch 39 Loss 0.8946 Accuracy 0.2290
# Time taken for 1 epoch: 115.61801338195801 secs
#
# Epoch 40 Batch 0 Loss 0.8976 Accuracy 0.2207
# Epoch 40 Batch 50 Loss 0.8765 Accuracy 0.2316
# Epoch 40 Batch 100 Loss 0.8761 Accuracy 0.2317
# Epoch 40 Batch 150 Loss 0.8769 Accuracy 0.2316
# Epoch 40 Batch 200 Loss 0.8755 Accuracy 0.2308
# Epoch 40 Batch 250 Loss 0.8746 Accuracy 0.2312
# Epoch 40 Batch 300 Loss 0.8727 Accuracy 0.2316
# Epoch 40 Batch 350 Loss 0.8722 Accuracy 0.2316
# Epoch 40 Batch 400 Loss 0.8700 Accuracy 0.2315
# Epoch 40 Batch 450 Loss 0.8676 Accuracy 0.2316
# Epoch 40 Loss 0.8656 Accuracy 0.2318
# Time taken for 1 epoch: 115.54235911369324 secs
#
# Epoch 41 Batch 0 Loss 0.9144 Accuracy 0.2363
# Epoch 41 Batch 50 Loss 0.8590 Accuracy 0.2332
# Epoch 41 Batch 100 Loss 0.8525 Accuracy 0.2339
# Epoch 41 Batch 150 Loss 0.8521 Accuracy 0.2340
# Epoch 41 Batch 200 Loss 0.8484 Accuracy 0.2338
# Epoch 41 Batch 250 Loss 0.8493 Accuracy 0.2337
# Epoch 41 Batch 300 Loss 0.8467 Accuracy 0.2342
# Epoch 41 Batch 350 Loss 0.8462 Accuracy 0.2342
# Epoch 41 Batch 400 Loss 0.8442 Accuracy 0.2342
# Epoch 41 Batch 450 Loss 0.8420 Accuracy 0.2342
# Epoch 41 Loss 0.8394 Accuracy 0.2344
# Time taken for 1 epoch: 115.5853328704834 secs
#
# Epoch 42 Batch 0 Loss 0.8843 Accuracy 0.2554
# Epoch 42 Batch 50 Loss 0.8552 Accuracy 0.2333
# Epoch 42 Batch 100 Loss 0.8387 Accuracy 0.2355
# Epoch 42 Batch 150 Loss 0.8356 Accuracy 0.2359
# Epoch 42 Batch 200 Loss 0.8335 Accuracy 0.2353
# Epoch 42 Batch 250 Loss 0.8322 Accuracy 0.2354
# Epoch 42 Batch 300 Loss 0.8272 Accuracy 0.2357
# Epoch 42 Batch 350 Loss 0.8255 Accuracy 0.2359
# Epoch 42 Batch 400 Loss 0.8231 Accuracy 0.2359
# Epoch 42 Batch 450 Loss 0.8211 Accuracy 0.2361
# Epoch 42 Loss 0.8187 Accuracy 0.2361
# Time taken for 1 epoch: 115.56617259979248 secs
#
# Epoch 43 Batch 0 Loss 0.8779 Accuracy 0.2397
# Epoch 43 Batch 50 Loss 0.8228 Accuracy 0.2362
# Epoch 43 Batch 100 Loss 0.8156 Accuracy 0.2371
# Epoch 43 Batch 150 Loss 0.8112 Accuracy 0.2370
# Epoch 43 Batch 200 Loss 0.8083 Accuracy 0.2369
# Epoch 43 Batch 250 Loss 0.8057 Accuracy 0.2373
# Epoch 43 Batch 300 Loss 0.8023 Accuracy 0.2379
# Epoch 43 Batch 350 Loss 0.8016 Accuracy 0.2378
# Epoch 43 Batch 400 Loss 0.7996 Accuracy 0.2378
# Epoch 43 Batch 450 Loss 0.7977 Accuracy 0.2379
# Epoch 43 Loss 0.7946 Accuracy 0.2383
# Time taken for 1 epoch: 115.66101050376892 secs
#
# Epoch 44 Batch 0 Loss 0.7742 Accuracy 0.2329
# Epoch 44 Batch 50 Loss 0.7746 Accuracy 0.2404
# Epoch 44 Batch 100 Loss 0.7778 Accuracy 0.2415
# Epoch 44 Batch 150 Loss 0.7758 Accuracy 0.2405
# Epoch 44 Batch 200 Loss 0.7757 Accuracy 0.2401
# Epoch 44 Batch 250 Loss 0.7770 Accuracy 0.2398
# Epoch 44 Batch 300 Loss 0.7726 Accuracy 0.2405
# Epoch 44 Batch 350 Loss 0.7711 Accuracy 0.2407
# Epoch 44 Batch 400 Loss 0.7702 Accuracy 0.2405
# Epoch 44 Batch 450 Loss 0.7692 Accuracy 0.2406
# Epoch 44 Loss 0.7680 Accuracy 0.2407
# Time taken for 1 epoch: 115.43252754211426 secs
#
# Epoch 45 Batch 0 Loss 0.8208 Accuracy 0.2295
# Epoch 45 Batch 50 Loss 0.7627 Accuracy 0.2427
# Epoch 45 Batch 100 Loss 0.7614 Accuracy 0.2427
# Epoch 45 Batch 150 Loss 0.7608 Accuracy 0.2424
# Epoch 45 Batch 200 Loss 0.7615 Accuracy 0.2416
# Epoch 45 Batch 250 Loss 0.7586 Accuracy 0.2419
# Epoch 45 Batch 300 Loss 0.7577 Accuracy 0.2420
# Epoch 45 Batch 350 Loss 0.7551 Accuracy 0.2424
# Epoch 45 Batch 400 Loss 0.7539 Accuracy 0.2422
# Epoch 45 Batch 450 Loss 0.7521 Accuracy 0.2424
# Epoch 45 Loss 0.7503 Accuracy 0.2425
# Time taken for 1 epoch: 115.53740763664246 secs
#
# Epoch 46 Batch 0 Loss 0.8143 Accuracy 0.2554
# Epoch 46 Batch 50 Loss 0.7461 Accuracy 0.2432
# Epoch 46 Batch 100 Loss 0.7406 Accuracy 0.2443
# Epoch 46 Batch 150 Loss 0.7377 Accuracy 0.2440
# Epoch 46 Batch 200 Loss 0.7348 Accuracy 0.2437
# Epoch 46 Batch 250 Loss 0.7322 Accuracy 0.2438
# Epoch 46 Batch 300 Loss 0.7310 Accuracy 0.2439
# Epoch 46 Batch 350 Loss 0.7307 Accuracy 0.2441
# Epoch 46 Batch 400 Loss 0.7284 Accuracy 0.2440
# Epoch 46 Batch 450 Loss 0.7274 Accuracy 0.2441
# Epoch 46 Loss 0.7260 Accuracy 0.2442
# Time taken for 1 epoch: 115.42054462432861 secs
#
# Epoch 47 Batch 0 Loss 0.7441 Accuracy 0.2441
# Epoch 47 Batch 50 Loss 0.7237 Accuracy 0.2453
# Epoch 47 Batch 100 Loss 0.7212 Accuracy 0.2458
# Epoch 47 Batch 150 Loss 0.7217 Accuracy 0.2458
# Epoch 47 Batch 200 Loss 0.7199 Accuracy 0.2450
# Epoch 47 Batch 250 Loss 0.7187 Accuracy 0.2453
# Epoch 47 Batch 300 Loss 0.7153 Accuracy 0.2456
# Epoch 47 Batch 350 Loss 0.7134 Accuracy 0.2459
# Epoch 47 Batch 400 Loss 0.7120 Accuracy 0.2458
# Epoch 47 Batch 450 Loss 0.7114 Accuracy 0.2460
# Epoch 47 Loss 0.7097 Accuracy 0.2460
# Time taken for 1 epoch: 115.51500391960144 secs
#
# Epoch 48 Batch 0 Loss 0.6866 Accuracy 0.2451
# Epoch 48 Batch 50 Loss 0.7022 Accuracy 0.2481
# Epoch 48 Batch 100 Loss 0.6951 Accuracy 0.2490
# Epoch 48 Batch 150 Loss 0.6953 Accuracy 0.2483
# Epoch 48 Batch 200 Loss 0.6970 Accuracy 0.2474
# Epoch 48 Batch 250 Loss 0.6951 Accuracy 0.2475
# Epoch 48 Batch 300 Loss 0.6922 Accuracy 0.2480
# Epoch 48 Batch 350 Loss 0.6921 Accuracy 0.2480
# Epoch 48 Batch 400 Loss 0.6910 Accuracy 0.2478
# Epoch 48 Batch 450 Loss 0.6898 Accuracy 0.2480
# Epoch 48 Loss 0.6892 Accuracy 0.2480
# Time taken for 1 epoch: 115.42791247367859 secs
#
# Epoch 49 Batch 0 Loss 0.7759 Accuracy 0.2485
# Epoch 49 Batch 50 Loss 0.6869 Accuracy 0.2490
# Epoch 49 Batch 100 Loss 0.6866 Accuracy 0.2504
# Epoch 49 Batch 150 Loss 0.6839 Accuracy 0.2495
# Epoch 49 Batch 200 Loss 0.6801 Accuracy 0.2494
# Epoch 49 Batch 250 Loss 0.6797 Accuracy 0.2493
# Epoch 49 Batch 300 Loss 0.6763 Accuracy 0.2497
# Epoch 49 Batch 350 Loss 0.6762 Accuracy 0.2498
# Epoch 49 Batch 400 Loss 0.6740 Accuracy 0.2495
# Epoch 49 Batch 450 Loss 0.6716 Accuracy 0.2499
# Epoch 49 Loss 0.6688 Accuracy 0.2499
# Time taken for 1 epoch: 115.53943514823914 secs
#
# Epoch 50 Batch 0 Loss 0.6257 Accuracy 0.2485
# Epoch 50 Batch 50 Loss 0.6683 Accuracy 0.2502
# Epoch 50 Batch 100 Loss 0.6691 Accuracy 0.2513
# Epoch 50 Batch 150 Loss 0.6679 Accuracy 0.2514
# Epoch 50 Batch 200 Loss 0.6680 Accuracy 0.2505
# Epoch 50 Batch 250 Loss 0.6666 Accuracy 0.2507
# Epoch 50 Batch 300 Loss 0.6630 Accuracy 0.2509
# Epoch 50 Batch 350 Loss 0.6625 Accuracy 0.2511
# Epoch 50 Batch 400 Loss 0.6620 Accuracy 0.2509
# Epoch 50 Batch 450 Loss 0.6601 Accuracy 0.2511
# Epoch 50 Loss 0.6578 Accuracy 0.2512
# Time taken for 1 epoch: 115.66142749786377 secs
#
# Epoch 51 Batch 0 Loss 0.6847 Accuracy 0.2529
# Epoch 51 Batch 50 Loss 0.6483 Accuracy 0.2529
# Epoch 51 Batch 100 Loss 0.6482 Accuracy 0.2529
# Epoch 51 Batch 150 Loss 0.6477 Accuracy 0.2526
# Epoch 51 Batch 200 Loss 0.6463 Accuracy 0.2517
# Epoch 51 Batch 250 Loss 0.6463 Accuracy 0.2517
# Epoch 51 Batch 300 Loss 0.6448 Accuracy 0.2523
# Epoch 51 Batch 350 Loss 0.6447 Accuracy 0.2523
# Epoch 51 Batch 400 Loss 0.6433 Accuracy 0.2522
# Epoch 51 Batch 450 Loss 0.6417 Accuracy 0.2524
# Epoch 51 Loss 0.6397 Accuracy 0.2526
# Time taken for 1 epoch: 115.53827261924744 secs
#
# Epoch 52 Batch 0 Loss 0.6591 Accuracy 0.2422
# Epoch 52 Batch 50 Loss 0.6317 Accuracy 0.2534
# Epoch 52 Batch 100 Loss 0.6297 Accuracy 0.2548
# Epoch 52 Batch 150 Loss 0.6291 Accuracy 0.2549
# Epoch 52 Batch 200 Loss 0.6284 Accuracy 0.2538
# Epoch 52 Batch 250 Loss 0.6293 Accuracy 0.2538
# Epoch 52 Batch 300 Loss 0.6283 Accuracy 0.2540
# Epoch 52 Batch 350 Loss 0.6277 Accuracy 0.2541
# Epoch 52 Batch 400 Loss 0.6269 Accuracy 0.2539
# Epoch 52 Batch 450 Loss 0.6263 Accuracy 0.2541
# Epoch 52 Loss 0.6239 Accuracy 0.2544
# Time taken for 1 epoch: 115.47791934013367 secs
#
# Epoch 53 Batch 0 Loss 0.7377 Accuracy 0.2300
# Epoch 53 Batch 50 Loss 0.6286 Accuracy 0.2539
# Epoch 53 Batch 100 Loss 0.6202 Accuracy 0.2555
# Epoch 53 Batch 150 Loss 0.6191 Accuracy 0.2556
# Epoch 53 Batch 200 Loss 0.6184 Accuracy 0.2550
# Epoch 53 Batch 250 Loss 0.6178 Accuracy 0.2555
# Epoch 53 Batch 300 Loss 0.6145 Accuracy 0.2557
# Epoch 53 Batch 350 Loss 0.6147 Accuracy 0.2556
# Epoch 53 Batch 400 Loss 0.6135 Accuracy 0.2554
# Epoch 53 Batch 450 Loss 0.6124 Accuracy 0.2555
# Epoch 53 Loss 0.6107 Accuracy 0.2556
# Time taken for 1 epoch: 115.55132985115051 secs
#
# Epoch 54 Batch 0 Loss 0.6980 Accuracy 0.2456
# Epoch 54 Batch 50 Loss 0.6126 Accuracy 0.2536
# Epoch 54 Batch 100 Loss 0.6053 Accuracy 0.2574
# Epoch 54 Batch 150 Loss 0.6033 Accuracy 0.2566
# Epoch 54 Batch 200 Loss 0.6024 Accuracy 0.2562
# Epoch 54 Batch 250 Loss 0.6030 Accuracy 0.2565
# Epoch 54 Batch 300 Loss 0.6021 Accuracy 0.2566
# Epoch 54 Batch 350 Loss 0.6018 Accuracy 0.2565
# Epoch 54 Batch 400 Loss 0.6002 Accuracy 0.2566
# Epoch 54 Batch 450 Loss 0.5996 Accuracy 0.2565
# Epoch 54 Loss 0.5982 Accuracy 0.2567
# Time taken for 1 epoch: 115.33892250061035 secs
#
# Epoch 55 Batch 0 Loss 0.6579 Accuracy 0.2407
# Epoch 55 Batch 50 Loss 0.5911 Accuracy 0.2581
# Epoch 55 Batch 100 Loss 0.5952 Accuracy 0.2577
# Epoch 55 Batch 150 Loss 0.5930 Accuracy 0.2581
# Epoch 55 Batch 200 Loss 0.5903 Accuracy 0.2577
# Epoch 55 Batch 250 Loss 0.5891 Accuracy 0.2575
# Epoch 55 Batch 300 Loss 0.5894 Accuracy 0.2578
# Epoch 55 Batch 350 Loss 0.5875 Accuracy 0.2576
# Epoch 55 Batch 400 Loss 0.5865 Accuracy 0.2577
# Epoch 55 Batch 450 Loss 0.5862 Accuracy 0.2579
# Epoch 55 Loss 0.5848 Accuracy 0.2579
# Time taken for 1 epoch: 115.55148530006409 secs
#
# Epoch 56 Batch 0 Loss 0.6271 Accuracy 0.2544
# Epoch 56 Batch 50 Loss 0.5790 Accuracy 0.2597
# Epoch 56 Batch 100 Loss 0.5805 Accuracy 0.2605
# Epoch 56 Batch 150 Loss 0.5784 Accuracy 0.2596
# Epoch 56 Batch 200 Loss 0.5781 Accuracy 0.2586
# Epoch 56 Batch 250 Loss 0.5747 Accuracy 0.2592
# Epoch 56 Batch 300 Loss 0.5745 Accuracy 0.2594
# Epoch 56 Batch 350 Loss 0.5743 Accuracy 0.2592
# Epoch 56 Batch 400 Loss 0.5732 Accuracy 0.2591
# Epoch 56 Batch 450 Loss 0.5711 Accuracy 0.2595
# Epoch 56 Loss 0.5701 Accuracy 0.2594
# Time taken for 1 epoch: 115.45882749557495 secs
#
# Epoch 57 Batch 0 Loss 0.6834 Accuracy 0.2266
# Epoch 57 Batch 50 Loss 0.5698 Accuracy 0.2599
# Epoch 57 Batch 100 Loss 0.5616 Accuracy 0.2621
# Epoch 57 Batch 150 Loss 0.5606 Accuracy 0.2614
# Epoch 57 Batch 200 Loss 0.5626 Accuracy 0.2606
# Epoch 57 Batch 250 Loss 0.5608 Accuracy 0.2606
# Epoch 57 Batch 300 Loss 0.5608 Accuracy 0.2609
# Epoch 57 Batch 350 Loss 0.5614 Accuracy 0.2607
# Epoch 57 Batch 400 Loss 0.5601 Accuracy 0.2607
# Epoch 57 Batch 450 Loss 0.5590 Accuracy 0.2607
# Epoch 57 Loss 0.5585 Accuracy 0.2606
# Time taken for 1 epoch: 115.53535676002502 secs
#
# Epoch 58 Batch 0 Loss 0.6334 Accuracy 0.2510
# Epoch 58 Batch 50 Loss 0.5599 Accuracy 0.2605
# Epoch 58 Batch 100 Loss 0.5578 Accuracy 0.2623
# Epoch 58 Batch 150 Loss 0.5573 Accuracy 0.2615
# Epoch 58 Batch 200 Loss 0.5555 Accuracy 0.2613
# Epoch 58 Batch 250 Loss 0.5523 Accuracy 0.2615
# Epoch 58 Batch 300 Loss 0.5522 Accuracy 0.2617
# Epoch 58 Batch 350 Loss 0.5506 Accuracy 0.2618
# Epoch 58 Batch 400 Loss 0.5495 Accuracy 0.2617
# Epoch 58 Batch 450 Loss 0.5476 Accuracy 0.2620
# Epoch 58 Loss 0.5463 Accuracy 0.2620
# Time taken for 1 epoch: 115.45556712150574 secs
#
# Epoch 59 Batch 0 Loss 0.6644 Accuracy 0.2681
# Epoch 59 Batch 50 Loss 0.5501 Accuracy 0.2615
# Epoch 59 Batch 100 Loss 0.5441 Accuracy 0.2634
# Epoch 59 Batch 150 Loss 0.5434 Accuracy 0.2630
# Epoch 59 Batch 200 Loss 0.5412 Accuracy 0.2623
# Epoch 59 Batch 250 Loss 0.5401 Accuracy 0.2624
# Epoch 59 Batch 300 Loss 0.5382 Accuracy 0.2629
# Epoch 59 Batch 350 Loss 0.5374 Accuracy 0.2629
# Epoch 59 Batch 400 Loss 0.5362 Accuracy 0.2625
# Epoch 59 Batch 450 Loss 0.5341 Accuracy 0.2631
# Epoch 59 Loss 0.5333 Accuracy 0.2631
# Time taken for 1 epoch: 115.51667737960815 secs
#
# Epoch 60 Batch 0 Loss 0.5913 Accuracy 0.2495
# Epoch 60 Batch 50 Loss 0.5312 Accuracy 0.2640
# Epoch 60 Batch 100 Loss 0.5298 Accuracy 0.2646
# Epoch 60 Batch 150 Loss 0.5305 Accuracy 0.2643
# Epoch 60 Batch 200 Loss 0.5293 Accuracy 0.2634
# Epoch 60 Batch 250 Loss 0.5275 Accuracy 0.2638
# Epoch 60 Batch 300 Loss 0.5271 Accuracy 0.2640
# Epoch 60 Batch 350 Loss 0.5263 Accuracy 0.2639
# Epoch 60 Batch 400 Loss 0.5255 Accuracy 0.2638
# Epoch 60 Batch 450 Loss 0.5247 Accuracy 0.2641
# Epoch 60 Loss 0.5247 Accuracy 0.2639
# Time taken for 1 epoch: 115.559396982193 secs
#
# Epoch 61 Batch 0 Loss 0.6941 Accuracy 0.2534
# Epoch 61 Batch 50 Loss 0.5244 Accuracy 0.2655
# Epoch 61 Batch 100 Loss 0.5213 Accuracy 0.2660
# Epoch 61 Batch 150 Loss 0.5175 Accuracy 0.2657
# Epoch 61 Batch 200 Loss 0.5180 Accuracy 0.2649
# Epoch 61 Batch 250 Loss 0.5187 Accuracy 0.2645
# Epoch 61 Batch 300 Loss 0.5174 Accuracy 0.2648
# Epoch 61 Batch 350 Loss 0.5173 Accuracy 0.2648
# Epoch 61 Batch 400 Loss 0.5162 Accuracy 0.2646
# Epoch 61 Batch 450 Loss 0.5160 Accuracy 0.2647
# Epoch 61 Loss 0.5142 Accuracy 0.2648
# Time taken for 1 epoch: 115.63285899162292 secs
#
# Epoch 62 Batch 0 Loss 0.6515 Accuracy 0.2485
# Epoch 62 Batch 50 Loss 0.5152 Accuracy 0.2646
# Epoch 62 Batch 100 Loss 0.5090 Accuracy 0.2665
# Epoch 62 Batch 150 Loss 0.5082 Accuracy 0.2662
# Epoch 62 Batch 200 Loss 0.5055 Accuracy 0.2661
# Epoch 62 Batch 250 Loss 0.5068 Accuracy 0.2660
# Epoch 62 Batch 300 Loss 0.5040 Accuracy 0.2663
# Epoch 62 Batch 350 Loss 0.5029 Accuracy 0.2665
# Epoch 62 Batch 400 Loss 0.5014 Accuracy 0.2665
# Epoch 62 Batch 450 Loss 0.5007 Accuracy 0.2665
# Epoch 62 Loss 0.4995 Accuracy 0.2665
# Time taken for 1 epoch: 115.52716588973999 secs
#
# Epoch 63 Batch 0 Loss 0.5604 Accuracy 0.2676
# Epoch 63 Batch 50 Loss 0.5019 Accuracy 0.2671
# Epoch 63 Batch 100 Loss 0.4977 Accuracy 0.2686
# Epoch 63 Batch 150 Loss 0.4982 Accuracy 0.2676
# Epoch 63 Batch 200 Loss 0.4992 Accuracy 0.2669
# Epoch 63 Batch 250 Loss 0.4984 Accuracy 0.2670
# Epoch 63 Batch 300 Loss 0.4964 Accuracy 0.2671
# Epoch 63 Batch 350 Loss 0.4955 Accuracy 0.2671
# Epoch 63 Batch 400 Loss 0.4938 Accuracy 0.2672
# Epoch 63 Batch 450 Loss 0.4937 Accuracy 0.2672
# Epoch 63 Loss 0.4926 Accuracy 0.2672
# Time taken for 1 epoch: 115.50576186180115 secs
#
# Epoch 64 Batch 0 Loss 0.5609 Accuracy 0.2520
# Epoch 64 Batch 50 Loss 0.5048 Accuracy 0.2660
# Epoch 64 Batch 100 Loss 0.4978 Accuracy 0.2680
# Epoch 64 Batch 150 Loss 0.4951 Accuracy 0.2676
# Epoch 64 Batch 200 Loss 0.4900 Accuracy 0.2672
# Epoch 64 Batch 250 Loss 0.4887 Accuracy 0.2677
# Epoch 64 Batch 300 Loss 0.4865 Accuracy 0.2680
# Epoch 64 Batch 350 Loss 0.4874 Accuracy 0.2679
# Epoch 64 Batch 400 Loss 0.4868 Accuracy 0.2676
# Epoch 64 Batch 450 Loss 0.4853 Accuracy 0.2678
# Epoch 64 Loss 0.4838 Accuracy 0.2679
# Time taken for 1 epoch: 115.36146402359009 secs
#
# Epoch 65 Batch 0 Loss 0.5335 Accuracy 0.2598
# Epoch 65 Batch 50 Loss 0.4762 Accuracy 0.2690
# Epoch 65 Batch 100 Loss 0.4786 Accuracy 0.2704
# Epoch 65 Batch 150 Loss 0.4806 Accuracy 0.2694
# Epoch 65 Batch 200 Loss 0.4791 Accuracy 0.2685
# Epoch 65 Batch 250 Loss 0.4781 Accuracy 0.2687
# Epoch 65 Batch 300 Loss 0.4756 Accuracy 0.2691
# Epoch 65 Batch 350 Loss 0.4745 Accuracy 0.2692
# Epoch 65 Batch 400 Loss 0.4745 Accuracy 0.2690
# Epoch 65 Batch 450 Loss 0.4735 Accuracy 0.2692
# Epoch 65 Loss 0.4720 Accuracy 0.2692
# Time taken for 1 epoch: 115.52252054214478 secs
#
# Epoch 66 Batch 0 Loss 0.5244 Accuracy 0.2793
# Epoch 66 Batch 50 Loss 0.4756 Accuracy 0.2685
# Epoch 66 Batch 100 Loss 0.4748 Accuracy 0.2701
# Epoch 66 Batch 150 Loss 0.4721 Accuracy 0.2702
# Epoch 66 Batch 200 Loss 0.4733 Accuracy 0.2692
# Epoch 66 Batch 250 Loss 0.4716 Accuracy 0.2694
# Epoch 66 Batch 300 Loss 0.4693 Accuracy 0.2697
# Epoch 66 Batch 350 Loss 0.4682 Accuracy 0.2698
# Epoch 66 Batch 400 Loss 0.4676 Accuracy 0.2698
# Epoch 66 Batch 450 Loss 0.4669 Accuracy 0.2697
# Epoch 66 Loss 0.4654 Accuracy 0.2698
# Time taken for 1 epoch: 115.45133543014526 secs
#
# Epoch 67 Batch 0 Loss 0.5618 Accuracy 0.2407
# Epoch 67 Batch 50 Loss 0.4667 Accuracy 0.2702
# Epoch 67 Batch 100 Loss 0.4609 Accuracy 0.2715
# Epoch 67 Batch 150 Loss 0.4600 Accuracy 0.2709
# Epoch 67 Batch 200 Loss 0.4573 Accuracy 0.2708
# Epoch 67 Batch 250 Loss 0.4576 Accuracy 0.2706
# Epoch 67 Batch 300 Loss 0.4568 Accuracy 0.2711
# Epoch 67 Batch 350 Loss 0.4571 Accuracy 0.2711
# Epoch 67 Batch 400 Loss 0.4564 Accuracy 0.2710
# Epoch 67 Batch 450 Loss 0.4562 Accuracy 0.2710
# Epoch 67 Loss 0.4551 Accuracy 0.2710
# Time taken for 1 epoch: 115.55365991592407 secs
#
# Epoch 68 Batch 0 Loss 0.4740 Accuracy 0.2539
# Epoch 68 Batch 50 Loss 0.4620 Accuracy 0.2702
# Epoch 68 Batch 100 Loss 0.4601 Accuracy 0.2714
# Epoch 68 Batch 150 Loss 0.4560 Accuracy 0.2714
# Epoch 68 Batch 200 Loss 0.4530 Accuracy 0.2713
# Epoch 68 Batch 250 Loss 0.4518 Accuracy 0.2714
# Epoch 68 Batch 300 Loss 0.4507 Accuracy 0.2714
# Epoch 68 Batch 350 Loss 0.4502 Accuracy 0.2715
# Epoch 68 Batch 400 Loss 0.4502 Accuracy 0.2714
# Epoch 68 Batch 450 Loss 0.4499 Accuracy 0.2714
# Epoch 68 Loss 0.4483 Accuracy 0.2717
# Time taken for 1 epoch: 115.44588232040405 secs
#
# Epoch 69 Batch 0 Loss 0.4810 Accuracy 0.2729
# Epoch 69 Batch 50 Loss 0.4451 Accuracy 0.2720
# Epoch 69 Batch 100 Loss 0.4428 Accuracy 0.2731
# Epoch 69 Batch 150 Loss 0.4445 Accuracy 0.2725
# Epoch 69 Batch 200 Loss 0.4443 Accuracy 0.2722
# Epoch 69 Batch 250 Loss 0.4450 Accuracy 0.2721
# Epoch 69 Batch 300 Loss 0.4436 Accuracy 0.2727
# Epoch 69 Batch 350 Loss 0.4438 Accuracy 0.2723
# Epoch 69 Batch 400 Loss 0.4436 Accuracy 0.2721
# Epoch 69 Batch 450 Loss 0.4427 Accuracy 0.2724
# Epoch 69 Loss 0.4421 Accuracy 0.2723
# Time taken for 1 epoch: 115.50333094596863 secs
#
# Epoch 70 Batch 0 Loss 0.5542 Accuracy 0.2456
# Epoch 70 Batch 50 Loss 0.4468 Accuracy 0.2714
# Epoch 70 Batch 100 Loss 0.4386 Accuracy 0.2739
# Epoch 70 Batch 150 Loss 0.4361 Accuracy 0.2736
# Epoch 70 Batch 200 Loss 0.4369 Accuracy 0.2724
# Epoch 70 Batch 250 Loss 0.4368 Accuracy 0.2729
# Epoch 70 Batch 300 Loss 0.4349 Accuracy 0.2732
# Epoch 70 Batch 350 Loss 0.4330 Accuracy 0.2734
# Epoch 70 Batch 400 Loss 0.4325 Accuracy 0.2733
# Epoch 70 Batch 450 Loss 0.4316 Accuracy 0.2734
# Epoch 70 Loss 0.4308 Accuracy 0.2734
# Time taken for 1 epoch: 115.47271633148193 secs
#
# Epoch 71 Batch 0 Loss 0.4932 Accuracy 0.2471
# Epoch 71 Batch 50 Loss 0.4329 Accuracy 0.2735
# Epoch 71 Batch 100 Loss 0.4296 Accuracy 0.2751
# Epoch 71 Batch 150 Loss 0.4297 Accuracy 0.2744
# Epoch 71 Batch 200 Loss 0.4292 Accuracy 0.2736
# Epoch 71 Batch 250 Loss 0.4313 Accuracy 0.2734
# Epoch 71 Batch 300 Loss 0.4290 Accuracy 0.2739
# Epoch 71 Batch 350 Loss 0.4277 Accuracy 0.2740
# Epoch 71 Batch 400 Loss 0.4279 Accuracy 0.2738
# Epoch 71 Batch 450 Loss 0.4275 Accuracy 0.2738
# Epoch 71 Loss 0.4264 Accuracy 0.2736
# Time taken for 1 epoch: 115.48002648353577 secs
#
# Epoch 72 Batch 0 Loss 0.5112 Accuracy 0.2681
# Epoch 72 Batch 50 Loss 0.4295 Accuracy 0.2750
# Epoch 72 Batch 100 Loss 0.4288 Accuracy 0.2748
# Epoch 72 Batch 150 Loss 0.4277 Accuracy 0.2746
# Epoch 72 Batch 200 Loss 0.4253 Accuracy 0.2740
# Epoch 72 Batch 250 Loss 0.4251 Accuracy 0.2741
# Epoch 72 Batch 300 Loss 0.4233 Accuracy 0.2744
# Epoch 72 Batch 350 Loss 0.4226 Accuracy 0.2744
# Epoch 72 Batch 400 Loss 0.4227 Accuracy 0.2742
# Epoch 72 Batch 450 Loss 0.4220 Accuracy 0.2743
# Epoch 72 Loss 0.4205 Accuracy 0.2744
# Time taken for 1 epoch: 115.49685001373291 secs
#
# Epoch 73 Batch 0 Loss 0.5330 Accuracy 0.2422
# Epoch 73 Batch 50 Loss 0.4179 Accuracy 0.2759
# Epoch 73 Batch 100 Loss 0.4162 Accuracy 0.2765
# Epoch 73 Batch 150 Loss 0.4159 Accuracy 0.2755
# Epoch 73 Batch 200 Loss 0.4164 Accuracy 0.2748
# Epoch 73 Batch 250 Loss 0.4194 Accuracy 0.2745
# Epoch 73 Batch 300 Loss 0.4179 Accuracy 0.2748
# Epoch 73 Batch 350 Loss 0.4172 Accuracy 0.2748
# Epoch 73 Batch 400 Loss 0.4159 Accuracy 0.2747
# Epoch 73 Batch 450 Loss 0.4149 Accuracy 0.2751
# Epoch 73 Loss 0.4141 Accuracy 0.2750
# Time taken for 1 epoch: 115.50706148147583 secs
#
# Epoch 74 Batch 0 Loss 0.4133 Accuracy 0.2505
# Epoch 74 Batch 50 Loss 0.4154 Accuracy 0.2756
# Epoch 74 Batch 100 Loss 0.4100 Accuracy 0.2770
# Epoch 74 Batch 150 Loss 0.4054 Accuracy 0.2770
# Epoch 74 Batch 200 Loss 0.4062 Accuracy 0.2760
# Epoch 74 Batch 250 Loss 0.4077 Accuracy 0.2760
# Epoch 74 Batch 300 Loss 0.4082 Accuracy 0.2760
# Epoch 74 Batch 350 Loss 0.4075 Accuracy 0.2760
# Epoch 74 Batch 400 Loss 0.4081 Accuracy 0.2759
# Epoch 74 Batch 450 Loss 0.4082 Accuracy 0.2758
# Epoch 74 Loss 0.4074 Accuracy 0.2758
# Time taken for 1 epoch: 115.34808659553528 secs
#
# Epoch 75 Batch 0 Loss 0.5046 Accuracy 0.2666
# Epoch 75 Batch 50 Loss 0.4121 Accuracy 0.2768
# Epoch 75 Batch 100 Loss 0.4083 Accuracy 0.2780
# Epoch 75 Batch 150 Loss 0.4046 Accuracy 0.2777
# Epoch 75 Batch 200 Loss 0.4055 Accuracy 0.2764
# Epoch 75 Batch 250 Loss 0.4040 Accuracy 0.2763
# Epoch 75 Batch 300 Loss 0.4039 Accuracy 0.2768
# Epoch 75 Batch 350 Loss 0.4032 Accuracy 0.2766
# Epoch 75 Batch 400 Loss 0.4018 Accuracy 0.2768
# Epoch 75 Batch 450 Loss 0.4017 Accuracy 0.2766
# Epoch 75 Loss 0.4004 Accuracy 0.2767
# Time taken for 1 epoch: 115.50305652618408 secs
#
# Epoch 76 Batch 0 Loss 0.4907 Accuracy 0.2617
# Epoch 76 Batch 50 Loss 0.3956 Accuracy 0.2785
# Epoch 76 Batch 100 Loss 0.3948 Accuracy 0.2785
# Epoch 76 Batch 150 Loss 0.3954 Accuracy 0.2777
# Epoch 76 Batch 200 Loss 0.3981 Accuracy 0.2764
# Epoch 76 Batch 250 Loss 0.3968 Accuracy 0.2768
# Epoch 76 Batch 300 Loss 0.3958 Accuracy 0.2771
# Epoch 76 Batch 350 Loss 0.3957 Accuracy 0.2769
# Epoch 76 Batch 400 Loss 0.3961 Accuracy 0.2767
# Epoch 76 Batch 450 Loss 0.3956 Accuracy 0.2767
# Epoch 76 Loss 0.3944 Accuracy 0.2768
# Time taken for 1 epoch: 115.51212120056152 secs
#
# Epoch 77 Batch 0 Loss 0.4744 Accuracy 0.2617
# Epoch 77 Batch 50 Loss 0.3895 Accuracy 0.2789
# Epoch 77 Batch 100 Loss 0.3921 Accuracy 0.2793
# Epoch 77 Batch 150 Loss 0.3905 Accuracy 0.2787
# Epoch 77 Batch 200 Loss 0.3893 Accuracy 0.2780
# Epoch 77 Batch 250 Loss 0.3889 Accuracy 0.2780
# Epoch 77 Batch 300 Loss 0.3890 Accuracy 0.2778
# Epoch 77 Batch 350 Loss 0.3888 Accuracy 0.2777
# Epoch 77 Batch 400 Loss 0.3881 Accuracy 0.2775
# Epoch 77 Batch 450 Loss 0.3878 Accuracy 0.2778
# Epoch 77 Loss 0.3870 Accuracy 0.2777
# Time taken for 1 epoch: 115.49417734146118 secs
#
# Epoch 78 Batch 0 Loss 0.4711 Accuracy 0.2593
# Epoch 78 Batch 50 Loss 0.3854 Accuracy 0.2784
# Epoch 78 Batch 100 Loss 0.3834 Accuracy 0.2792
# Epoch 78 Batch 150 Loss 0.3834 Accuracy 0.2790
# Epoch 78 Batch 200 Loss 0.3835 Accuracy 0.2782
# Epoch 78 Batch 250 Loss 0.3851 Accuracy 0.2782
# Epoch 78 Batch 300 Loss 0.3847 Accuracy 0.2783
# Epoch 78 Batch 350 Loss 0.3851 Accuracy 0.2783
# Epoch 78 Batch 400 Loss 0.3837 Accuracy 0.2781
# Epoch 78 Batch 450 Loss 0.3836 Accuracy 0.2781
# Epoch 78 Loss 0.3826 Accuracy 0.2781
# Time taken for 1 epoch: 115.40510582923889 secs
#
# Epoch 79 Batch 0 Loss 0.4679 Accuracy 0.2725
# Epoch 79 Batch 50 Loss 0.3905 Accuracy 0.2777
# Epoch 79 Batch 100 Loss 0.3857 Accuracy 0.2791
# Epoch 79 Batch 150 Loss 0.3855 Accuracy 0.2789
# Epoch 79 Batch 200 Loss 0.3844 Accuracy 0.2781
# Epoch 79 Batch 250 Loss 0.3840 Accuracy 0.2784
# Epoch 79 Batch 300 Loss 0.3822 Accuracy 0.2789
# Epoch 79 Batch 350 Loss 0.3816 Accuracy 0.2786
# Epoch 79 Batch 400 Loss 0.3813 Accuracy 0.2785
# Epoch 79 Batch 450 Loss 0.3804 Accuracy 0.2786
# Epoch 79 Loss 0.3790 Accuracy 0.2787
# Time taken for 1 epoch: 115.56009316444397 secs
#
# Epoch 80 Batch 0 Loss 0.4646 Accuracy 0.2505
# Epoch 80 Batch 50 Loss 0.3852 Accuracy 0.2780
# Epoch 80 Batch 100 Loss 0.3782 Accuracy 0.2808
# Epoch 80 Batch 150 Loss 0.3793 Accuracy 0.2798
# Epoch 80 Batch 200 Loss 0.3789 Accuracy 0.2791
# Epoch 80 Batch 250 Loss 0.3781 Accuracy 0.2789
# Epoch 80 Batch 300 Loss 0.3764 Accuracy 0.2793
# Epoch 80 Batch 350 Loss 0.3765 Accuracy 0.2792
# Epoch 80 Batch 400 Loss 0.3759 Accuracy 0.2791
# Epoch 80 Batch 450 Loss 0.3758 Accuracy 0.2789
# Epoch 80 Loss 0.3743 Accuracy 0.2792
# Time taken for 1 epoch: 115.47706317901611 secs
#
# Epoch 81 Batch 0 Loss 0.4809 Accuracy 0.2632
# Epoch 81 Batch 50 Loss 0.3800 Accuracy 0.2793
# Epoch 81 Batch 100 Loss 0.3719 Accuracy 0.2806
# Epoch 81 Batch 150 Loss 0.3725 Accuracy 0.2808
# Epoch 81 Batch 200 Loss 0.3710 Accuracy 0.2794
# Epoch 81 Batch 250 Loss 0.3686 Accuracy 0.2798
# Epoch 81 Batch 300 Loss 0.3687 Accuracy 0.2800
# Epoch 81 Batch 350 Loss 0.3683 Accuracy 0.2799
# Epoch 81 Batch 400 Loss 0.3681 Accuracy 0.2797
# Epoch 81 Batch 450 Loss 0.3686 Accuracy 0.2798
# Epoch 81 Loss 0.3677 Accuracy 0.2798
# Time taken for 1 epoch: 115.499272108078 secs
#
# Epoch 82 Batch 0 Loss 0.5040 Accuracy 0.2651
# Epoch 82 Batch 50 Loss 0.3666 Accuracy 0.2805
# Epoch 82 Batch 100 Loss 0.3678 Accuracy 0.2807
# Epoch 82 Batch 150 Loss 0.3664 Accuracy 0.2802
# Epoch 82 Batch 200 Loss 0.3656 Accuracy 0.2799
# Epoch 82 Batch 250 Loss 0.3654 Accuracy 0.2804
# Epoch 82 Batch 300 Loss 0.3647 Accuracy 0.2804
# Epoch 82 Batch 350 Loss 0.3651 Accuracy 0.2804
# Epoch 82 Batch 400 Loss 0.3651 Accuracy 0.2802
# Epoch 82 Batch 450 Loss 0.3640 Accuracy 0.2803
# Epoch 82 Loss 0.3626 Accuracy 0.2803
# Time taken for 1 epoch: 115.59437274932861 secs
#
# Epoch 83 Batch 0 Loss 0.5160 Accuracy 0.2642
# Epoch 83 Batch 50 Loss 0.3635 Accuracy 0.2805
# Epoch 83 Batch 100 Loss 0.3575 Accuracy 0.2833
# Epoch 83 Batch 150 Loss 0.3579 Accuracy 0.2818
# Epoch 83 Batch 200 Loss 0.3563 Accuracy 0.2811
# Epoch 83 Batch 250 Loss 0.3557 Accuracy 0.2812
# Epoch 83 Batch 300 Loss 0.3553 Accuracy 0.2817
# Epoch 83 Batch 350 Loss 0.3566 Accuracy 0.2813
# Epoch 83 Batch 400 Loss 0.3564 Accuracy 0.2811
# Epoch 83 Batch 450 Loss 0.3559 Accuracy 0.2811
# Epoch 83 Loss 0.3547 Accuracy 0.2812
# Time taken for 1 epoch: 115.57791233062744 secs
#
# Epoch 84 Batch 0 Loss 0.4651 Accuracy 0.2681
# Epoch 84 Batch 50 Loss 0.3559 Accuracy 0.2828
# Epoch 84 Batch 100 Loss 0.3543 Accuracy 0.2830
# Epoch 84 Batch 150 Loss 0.3534 Accuracy 0.2824
# Epoch 84 Batch 200 Loss 0.3517 Accuracy 0.2817
# Epoch 84 Batch 250 Loss 0.3527 Accuracy 0.2814
# Epoch 84 Batch 300 Loss 0.3526 Accuracy 0.2817
# Epoch 84 Batch 350 Loss 0.3531 Accuracy 0.2814
# Epoch 84 Batch 400 Loss 0.3540 Accuracy 0.2812
# Epoch 84 Batch 450 Loss 0.3537 Accuracy 0.2813
# Epoch 84 Loss 0.3525 Accuracy 0.2814
# Time taken for 1 epoch: 115.346271276474 secs
#
# Epoch 85 Batch 0 Loss 0.4865 Accuracy 0.2534
# Epoch 85 Batch 50 Loss 0.3480 Accuracy 0.2836
# Epoch 85 Batch 100 Loss 0.3452 Accuracy 0.2839
# Epoch 85 Batch 150 Loss 0.3481 Accuracy 0.2830
# Epoch 85 Batch 200 Loss 0.3494 Accuracy 0.2818
# Epoch 85 Batch 250 Loss 0.3467 Accuracy 0.2822
# Epoch 85 Batch 300 Loss 0.3462 Accuracy 0.2823
# Epoch 85 Batch 350 Loss 0.3462 Accuracy 0.2824
# Epoch 85 Batch 400 Loss 0.3480 Accuracy 0.2820
# Epoch 85 Batch 450 Loss 0.3489 Accuracy 0.2820
# Epoch 85 Loss 0.3480 Accuracy 0.2821
# Time taken for 1 epoch: 115.56365466117859 secs
#
# Epoch 86 Batch 0 Loss 0.3826 Accuracy 0.2910
# Epoch 86 Batch 50 Loss 0.3507 Accuracy 0.2833
# Epoch 86 Batch 100 Loss 0.3450 Accuracy 0.2840
# Epoch 86 Batch 150 Loss 0.3462 Accuracy 0.2830
# Epoch 86 Batch 200 Loss 0.3467 Accuracy 0.2823
# Epoch 86 Batch 250 Loss 0.3465 Accuracy 0.2822
# Epoch 86 Batch 300 Loss 0.3451 Accuracy 0.2824
# Epoch 86 Batch 350 Loss 0.3446 Accuracy 0.2826
# Epoch 86 Batch 400 Loss 0.3439 Accuracy 0.2824
# Epoch 86 Batch 450 Loss 0.3442 Accuracy 0.2824
# Epoch 86 Loss 0.3428 Accuracy 0.2824
# Time taken for 1 epoch: 115.41632533073425 secs
#
# Epoch 87 Batch 0 Loss 0.4287 Accuracy 0.2695
# Epoch 87 Batch 50 Loss 0.3428 Accuracy 0.2839
# Epoch 87 Batch 100 Loss 0.3412 Accuracy 0.2850
# Epoch 87 Batch 150 Loss 0.3426 Accuracy 0.2834
# Epoch 87 Batch 200 Loss 0.3389 Accuracy 0.2829
# Epoch 87 Batch 250 Loss 0.3398 Accuracy 0.2830
# Epoch 87 Batch 300 Loss 0.3402 Accuracy 0.2832
# Epoch 87 Batch 350 Loss 0.3407 Accuracy 0.2831
# Epoch 87 Batch 400 Loss 0.3395 Accuracy 0.2828
# Epoch 87 Batch 450 Loss 0.3403 Accuracy 0.2825
# Epoch 87 Loss 0.3385 Accuracy 0.2829
# Time taken for 1 epoch: 115.48625826835632 secs
#
# Epoch 88 Batch 0 Loss 0.3896 Accuracy 0.2783
# Epoch 88 Batch 50 Loss 0.3338 Accuracy 0.2834
# Epoch 88 Batch 100 Loss 0.3368 Accuracy 0.2846
# Epoch 88 Batch 150 Loss 0.3378 Accuracy 0.2839
# Epoch 88 Batch 200 Loss 0.3374 Accuracy 0.2827
# Epoch 88 Batch 250 Loss 0.3373 Accuracy 0.2830
# Epoch 88 Batch 300 Loss 0.3355 Accuracy 0.2836
# Epoch 88 Batch 350 Loss 0.3355 Accuracy 0.2834
# Epoch 88 Batch 400 Loss 0.3359 Accuracy 0.2830
# Epoch 88 Batch 450 Loss 0.3357 Accuracy 0.2833
# Epoch 88 Loss 0.3351 Accuracy 0.2831
# Time taken for 1 epoch: 115.35140466690063 secs
#
# Epoch 89 Batch 0 Loss 0.4155 Accuracy 0.2637
# Epoch 89 Batch 50 Loss 0.3291 Accuracy 0.2848
# Epoch 89 Batch 100 Loss 0.3357 Accuracy 0.2841
# Epoch 89 Batch 150 Loss 0.3352 Accuracy 0.2836
# Epoch 89 Batch 200 Loss 0.3328 Accuracy 0.2836
# Epoch 89 Batch 250 Loss 0.3335 Accuracy 0.2835
# Epoch 89 Batch 300 Loss 0.3333 Accuracy 0.2835
# Epoch 89 Batch 350 Loss 0.3331 Accuracy 0.2835
# Epoch 89 Batch 400 Loss 0.3335 Accuracy 0.2832
# Epoch 89 Batch 450 Loss 0.3322 Accuracy 0.2836
# Epoch 89 Loss 0.3306 Accuracy 0.2835
# Time taken for 1 epoch: 115.40857720375061 secs
#
# Epoch 90 Batch 0 Loss 0.4175 Accuracy 0.2920
# Epoch 90 Batch 50 Loss 0.3289 Accuracy 0.2838
# Epoch 90 Batch 100 Loss 0.3238 Accuracy 0.2856
# Epoch 90 Batch 150 Loss 0.3263 Accuracy 0.2848
# Epoch 90 Batch 200 Loss 0.3252 Accuracy 0.2841
# Epoch 90 Batch 250 Loss 0.3266 Accuracy 0.2839
# Epoch 90 Batch 300 Loss 0.3260 Accuracy 0.2844
# Epoch 90 Batch 350 Loss 0.3264 Accuracy 0.2844
# Epoch 90 Batch 400 Loss 0.3262 Accuracy 0.2841
# Epoch 90 Batch 450 Loss 0.3264 Accuracy 0.2841
# Epoch 90 Loss 0.3253 Accuracy 0.2842
# Time taken for 1 epoch: 115.43835067749023 secs
#
# Epoch 91 Batch 0 Loss 0.4073 Accuracy 0.2705
# Epoch 91 Batch 50 Loss 0.3261 Accuracy 0.2855
# Epoch 91 Batch 100 Loss 0.3224 Accuracy 0.2862
# Epoch 91 Batch 150 Loss 0.3248 Accuracy 0.2853
# Epoch 91 Batch 200 Loss 0.3266 Accuracy 0.2843
# Epoch 91 Batch 250 Loss 0.3257 Accuracy 0.2846
# Epoch 91 Batch 300 Loss 0.3257 Accuracy 0.2850
# Epoch 91 Batch 350 Loss 0.3257 Accuracy 0.2847
# Epoch 91 Batch 400 Loss 0.3247 Accuracy 0.2846
# Epoch 91 Batch 450 Loss 0.3246 Accuracy 0.2847
# Epoch 91 Loss 0.3238 Accuracy 0.2845
# Time taken for 1 epoch: 115.39879155158997 secs
#
# Epoch 92 Batch 0 Loss 0.4288 Accuracy 0.2686
# Epoch 92 Batch 50 Loss 0.3262 Accuracy 0.2844
# Epoch 92 Batch 100 Loss 0.3248 Accuracy 0.2858
# Epoch 92 Batch 150 Loss 0.3232 Accuracy 0.2850
# Epoch 92 Batch 200 Loss 0.3251 Accuracy 0.2837
# Epoch 92 Batch 250 Loss 0.3228 Accuracy 0.2844
# Epoch 92 Batch 300 Loss 0.3212 Accuracy 0.2849
# Epoch 92 Batch 350 Loss 0.3211 Accuracy 0.2847
# Epoch 92 Batch 400 Loss 0.3206 Accuracy 0.2847
# Epoch 92 Batch 450 Loss 0.3211 Accuracy 0.2846
# Epoch 92 Loss 0.3201 Accuracy 0.2847
# Time taken for 1 epoch: 115.45902562141418 secs
#
# Epoch 93 Batch 0 Loss 0.4088 Accuracy 0.2632
# Epoch 93 Batch 50 Loss 0.3186 Accuracy 0.2863
# Epoch 93 Batch 100 Loss 0.3181 Accuracy 0.2868
# Epoch 93 Batch 150 Loss 0.3161 Accuracy 0.2862
# Epoch 93 Batch 200 Loss 0.3179 Accuracy 0.2851
# Epoch 93 Batch 250 Loss 0.3171 Accuracy 0.2852
# Epoch 93 Batch 300 Loss 0.3164 Accuracy 0.2855
# Epoch 93 Batch 350 Loss 0.3174 Accuracy 0.2852
# Epoch 93 Batch 400 Loss 0.3169 Accuracy 0.2851
# Epoch 93 Batch 450 Loss 0.3159 Accuracy 0.2851
# Epoch 93 Loss 0.3150 Accuracy 0.2853
# Time taken for 1 epoch: 115.51117134094238 secs
#
# Epoch 94 Batch 0 Loss 0.4199 Accuracy 0.2637
# Epoch 94 Batch 50 Loss 0.3074 Accuracy 0.2884
# Epoch 94 Batch 100 Loss 0.3084 Accuracy 0.2877
# Epoch 94 Batch 150 Loss 0.3116 Accuracy 0.2866
# Epoch 94 Batch 200 Loss 0.3118 Accuracy 0.2856
# Epoch 94 Batch 250 Loss 0.3115 Accuracy 0.2859
# Epoch 94 Batch 300 Loss 0.3115 Accuracy 0.2860
# Epoch 94 Batch 350 Loss 0.3102 Accuracy 0.2860
# Epoch 94 Batch 400 Loss 0.3103 Accuracy 0.2859
# Epoch 94 Batch 450 Loss 0.3099 Accuracy 0.2859
# Epoch 94 Loss 0.3091 Accuracy 0.2859
# Time taken for 1 epoch: 115.3259608745575 secs
#
# Epoch 95 Batch 0 Loss 0.3815 Accuracy 0.2817
# Epoch 95 Batch 50 Loss 0.3089 Accuracy 0.2884
# Epoch 95 Batch 100 Loss 0.3105 Accuracy 0.2875
# Epoch 95 Batch 150 Loss 0.3105 Accuracy 0.2866
# Epoch 95 Batch 200 Loss 0.3107 Accuracy 0.2859
# Epoch 95 Batch 250 Loss 0.3107 Accuracy 0.2856
# Epoch 95 Batch 300 Loss 0.3100 Accuracy 0.2863
# Epoch 95 Batch 350 Loss 0.3101 Accuracy 0.2860
# Epoch 95 Batch 400 Loss 0.3106 Accuracy 0.2859
# Epoch 95 Batch 450 Loss 0.3105 Accuracy 0.2859
# Epoch 95 Loss 0.3088 Accuracy 0.2860
# Time taken for 1 epoch: 115.54492473602295 secs
#
# Epoch 96 Batch 0 Loss 0.3161 Accuracy 0.2817
# Epoch 96 Batch 50 Loss 0.3028 Accuracy 0.2869
# Epoch 96 Batch 100 Loss 0.3029 Accuracy 0.2878
# Epoch 96 Batch 150 Loss 0.3043 Accuracy 0.2874
# Epoch 96 Batch 200 Loss 0.3033 Accuracy 0.2869
# Epoch 96 Batch 250 Loss 0.3039 Accuracy 0.2866
# Epoch 96 Batch 300 Loss 0.3049 Accuracy 0.2868
# Epoch 96 Batch 350 Loss 0.3052 Accuracy 0.2866
# Epoch 96 Batch 400 Loss 0.3053 Accuracy 0.2864
# Epoch 96 Batch 450 Loss 0.3050 Accuracy 0.2863
# Epoch 96 Loss 0.3047 Accuracy 0.2864
# Time taken for 1 epoch: 115.4606032371521 secs
#
# Epoch 97 Batch 0 Loss 0.3960 Accuracy 0.2788
# Epoch 97 Batch 50 Loss 0.2978 Accuracy 0.2886
# Epoch 97 Batch 100 Loss 0.3039 Accuracy 0.2877
# Epoch 97 Batch 150 Loss 0.3034 Accuracy 0.2878
# Epoch 97 Batch 200 Loss 0.3043 Accuracy 0.2868
# Epoch 97 Batch 250 Loss 0.3038 Accuracy 0.2869
# Epoch 97 Batch 300 Loss 0.3027 Accuracy 0.2873
# Epoch 97 Batch 350 Loss 0.3030 Accuracy 0.2872
# Epoch 97 Batch 400 Loss 0.3039 Accuracy 0.2866
# Epoch 97 Batch 450 Loss 0.3034 Accuracy 0.2868
# Epoch 97 Loss 0.3027 Accuracy 0.2868
# Time taken for 1 epoch: 115.40701365470886 secs
#
# Epoch 98 Batch 0 Loss 0.3369 Accuracy 0.2661
# Epoch 98 Batch 50 Loss 0.2990 Accuracy 0.2881
# Epoch 98 Batch 100 Loss 0.2999 Accuracy 0.2890
# Epoch 98 Batch 150 Loss 0.2994 Accuracy 0.2877
# Epoch 98 Batch 200 Loss 0.2982 Accuracy 0.2871
# Epoch 98 Batch 250 Loss 0.2986 Accuracy 0.2873
# Epoch 98 Batch 300 Loss 0.2982 Accuracy 0.2876
# Epoch 98 Batch 350 Loss 0.2984 Accuracy 0.2872
# Epoch 98 Batch 400 Loss 0.2990 Accuracy 0.2870
# Epoch 98 Batch 450 Loss 0.2989 Accuracy 0.2869
# Epoch 98 Loss 0.2985 Accuracy 0.2870
# Time taken for 1 epoch: 115.41305947303772 secs
#
# Epoch 99 Batch 0 Loss 0.3666 Accuracy 0.2725
# Epoch 99 Batch 50 Loss 0.2980 Accuracy 0.2875
# Epoch 99 Batch 100 Loss 0.3014 Accuracy 0.2879
# Epoch 99 Batch 150 Loss 0.2982 Accuracy 0.2882
# Epoch 99 Batch 200 Loss 0.2980 Accuracy 0.2868
# Epoch 99 Batch 250 Loss 0.2975 Accuracy 0.2871
# Epoch 99 Batch 300 Loss 0.2957 Accuracy 0.2875
# Epoch 99 Batch 350 Loss 0.2946 Accuracy 0.2877
# Epoch 99 Batch 400 Loss 0.2953 Accuracy 0.2875
# Epoch 99 Batch 450 Loss 0.2945 Accuracy 0.2875
# Epoch 99 Loss 0.2942 Accuracy 0.2875
# Time taken for 1 epoch: 115.40004062652588 secs
#
# Epoch 100 Batch 0 Loss 0.3866 Accuracy 0.2534
# Epoch 100 Batch 50 Loss 0.2972 Accuracy 0.2869
# Epoch 100 Batch 100 Loss 0.2947 Accuracy 0.2890
# Epoch 100 Batch 150 Loss 0.2965 Accuracy 0.2878
# Epoch 100 Batch 200 Loss 0.2942 Accuracy 0.2875
# Epoch 100 Batch 250 Loss 0.2943 Accuracy 0.2874
# Epoch 100 Batch 300 Loss 0.2948 Accuracy 0.2877
# Epoch 100 Batch 350 Loss 0.2938 Accuracy 0.2878
# Epoch 100 Batch 400 Loss 0.2938 Accuracy 0.2878
# Epoch 100 Batch 450 Loss 0.2935 Accuracy 0.2876
# Epoch 100 Loss 0.2922 Accuracy 0.2877
# Time taken for 1 epoch: 115.48422694206238 secs

# %%
transformer.save_weights('image_caption_transformer_45.h5')

# %%
def evaluate(image):

  temp_input = tf.expand_dims(load_image(image)[0], 0)
  img_tensor_val = image_features_extract_model(temp_input)
  img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))
  
  start_token = tokenizer.word_index['<start>']
  end_token = tokenizer.word_index['<end>']
   
  #decoder input is start token.
  decoder_input = [start_token]
  output = tf.expand_dims(decoder_input, 0) #tokens
  result = [] #word list

  for i in range(100):
      dec_mask = create_masks_decoder(output)
  
      # predictions.shape == (batch_size, seq_len, vocab_size)
      predictions, attention_weights = transformer(img_tensor_val,output,False,dec_mask)
      
      # select the last word from the seq_len dimension
      predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)

      predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)
      # return the result if the predicted_id is equal to the end token
      if predicted_id == end_token:
          return result,tf.squeeze(output, axis=0), attention_weights
      # concatentate the predicted_id to the output which is given to the decoder
      # as its input.
      result.append(tokenizer.index_word[int(predicted_id)])
      output = tf.concat([output, predicted_id], axis=-1)

  return result,tf.squeeze(output, axis=0), attention_weights

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 11.111111111111109
# BLEU-2 score: 33.33333333333333
# BLEU-3 score: 51.72818579717866
# BLEU-4 score: 57.735026918962575
# Real Caption: little boy swims underwater
# Predicted Caption: boy in blue shirt is playing in the water

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 41.66666666666667
# BLEU-2 score: 64.54972243679028
# BLEU-3 score: 76.90182164956363
# BLEU-4 score: 80.34284189446518
# Real Caption: the old man has long white beard and yellow and black hat
# Predicted Caption: man in black shirt and white shirt is standing on the street

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 11.111111111111109
# BLEU-2 score: 33.33333333333333
# BLEU-3 score: 51.72818579717866
# BLEU-4 score: 57.735026918962575
# Real Caption: bicyclist jumping trick on bike
# Predicted Caption: man in black shirt is standing on the air

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 33.33333333333333
# BLEU-2 score: 57.735026918962575
# BLEU-3 score: 71.92230933248644
# BLEU-4 score: 75.98356856515926
# Real Caption: muzzled race dog running
# Predicted Caption: dog is running through the grass
